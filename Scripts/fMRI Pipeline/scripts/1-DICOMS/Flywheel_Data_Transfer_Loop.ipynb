# %% [markdown]
# # Transfer multiple participants
#
# This script allows you to loop through a list of participants.
#
# You'll probably want to use the test notebook (`Flywheel_Data_Transfer.ipynb`) first for one participants to create the credential config file and figure out the correct variable names.

# %%
import flywheel
import tarfile
import os
import time
import zipfile
from zipfile import ZipFile
import configparser

# %% [markdown]
# ## Define functions

# %%
def transfer_data (sub, in_prefix, out_prefix, in_project, out_project):
    ipID = in_prefix + sub
    opID = out_prefix + sub
    outpath = '/fmriDataRaw/fmri_data_raw/{PROJECT}'.format(PROJECT=out_project)
    
    if os.path.exists(os.path.join(outpath, opID)) == False:
        print('-------------- Transferring: {} -------------'.format(ipID))
        
        # download tar file
        session = fw.lookup('falklab/{proj}/{pid}'.format(proj=in_project,pid=ipID))
        print ('Downloading tar')
        fw.download_tar(session,'./working_data/{opID}.tar'.format(opID=opID))
        
        # open tar file
        with open("working_data/{opID}.tar".format(opID=opID), 'rb') as f: # <--- Flywheel download as Read Bytes
            print ('Opening tar in memory as:',f,'\n')
            tar_data = tarfile.open(fileobj=f, mode='r:') # <--- Unpack tar in memory
        
            # Create the directory if not exist
            output_dicom_dir = '{outpath}/{opID}/'.format(outpath=outpath,opID=opID)

            if not os.path.exists(os.path.dirname(output_dicom_dir)):
                try:
                    print('makedirs --> {}'.format(output_dicom_dir))
                    os.makedirs(os.path.dirname(output_dicom_dir))
                except:
                    print('oops! failed to create --> {}'.format(output_dicom_dir))     


            # Extract dicom files
            for member in tar_data.getmembers():
                if 'dicom.zip' in member.name:       # <--- Only extract files with 'dicom.zip' 
                    print('Extracting: {}\n'.format(member.name))

                    tfile = tar_data.extractfile(member.name)
                    dicom_zip = zipfile.ZipFile(tfile, mode='r')
                    dicom_zip.extractall(output_dicom_dir)

            print('Participant {} Complete\n'.format(sub))
        #tar_data.close()
    else:
        print('-------------- Skipping existing participant: {} -------------'.format(ipID))

# %% [markdown]
# ## Define variables
# * home_dir = home directory where the config file was created in the test notebook
# * in_project = project name on flywheel
# * out_project = desired output project name
# * subs = participant numbers minus the prefix (e.g. use 01 for bpp01)
# * in_prefix = project prefix listed on flywheel
# * out_prefix = desired project prefix

# %%
# home_dir = "/home/dcosme@asc.upenn.edu"
# in_project = 'bbprime'
# out_project = "bbprime"
# subs = ['21', '22', '23']
# in_prefix = 'bpp'
# out_prefix = 'BPP'

home_dir = "/home/bmuzekari@asc.upenn.edu"
in_project = 'geoscan'
out_project = "georemote"
subs = ['135','148','178','168','199','076','205','241','236','231','235','255','257','306','303']
in_prefix = 'GR'
out_prefix = 'GR'

# %% [markdown]
# ## Setup API

# %%
# add UPenn Flywheel api key to your config.ini
fw_cred = {}
config = configparser.ConfigParser()

config.read(home_dir + '/configs/config.ini') # <--- add your Twitter API tokens to this file!
for item,value in config['UPENN-FLYWHEEL'].items():
    fw_cred[item]=value

# read your API key
api = fw_cred['apikey']

# Create client using your API key
fw = flywheel.Client(api)

# print your flywheel information & confirm it works as expected
self = fw.get_current_user()
print('UPenn Flywheel User: %s %s (%s)' % 
      (self.firstname, self.lastname, self.email))
# Out:
# UPenn Flywheel User: Anthony Resnick (aresni@upenn.edu)

# %% [markdown]
# ## Loop through data

# %%
for sub in subs:
    transfer_data(sub, in_prefix, out_prefix, in_project, out_project)
# Out:
# -------------- Transferring: GR135 -------------
# Downloading tar
# Opening tar in memory as: <_io.BufferedReader name='working_data/GR135.tar'>
#
# makedirs --> /fmriDataRaw/fmri_data_raw/georemote/GR135/
# Extracting: scitran/falklab/geoscan/GR135/CAMRIS^Falk/localizer_multislice/1.3.12.2.1107.5.2.43.66044.2023072015252336440094760.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR135/CAMRIS^Falk/PhoenixZIPReport/1.3.12.2.1107.5.2.43.66044.30000023071402032364700000933.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR135/CAMRIS^Falk/AAHead_Scout/1.3.12.2.1107.5.2.43.66044.2023072015272713557695524.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR135/CAMRIS^Falk/AAHead_Scout_MPR_sag/1.3.12.2.1107.5.2.43.66044.2023072015273081394896610.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR135/CAMRIS^Falk/AAHead_Scout_MPR_cor/1.3.12.2.1107.5.2.43.66044.2023072015273081436396616.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR135/CAMRIS^Falk/AAHead_Scout_MPR_tra/1.3.12.2.1107.5.2.43.66044.2023072015273081461096620.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR135/CAMRIS^Falk/MPRAGE_TI1100_ipat2/1.3.12.2.1107.5.2.43.66044.2023072015290349116696941.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR135/CAMRIS^Falk/BOLD_IMAGE_run01/1.3.12.2.1107.5.2.43.66044.2023072015334355932798103.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR135/CAMRIS^Falk/FieldMap_PA/1.3.12.2.1107.5.2.43.66044.2023072015424428669916588.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR135/CAMRIS^Falk/BOLD_IMAGE_run02/1.3.12.2.1107.5.2.43.66044.2023072015430545111717153.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR135/CAMRIS^Falk/FieldMap_PA_1/1.3.12.2.1107.5.2.43.66044.2023072015504564325635638.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR135/CAMRIS^Falk/BOLD_IMAGE_run03/1.3.12.2.1107.5.2.43.66044.2023072015510684416336203.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR135/CAMRIS^Falk/FieldMap_PA_2/1.3.12.2.1107.5.2.43.66044.2023072015581249508454688.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR135/CAMRIS^Falk/BOLD_IMAGE_run04/1.3.12.2.1107.5.2.43.66044.2023072015583394781655253.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR135/CAMRIS^Falk/FieldMap_PA_3/1.3.12.2.1107.5.2.43.66044.2023072016053531319473738.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR135/CAMRIS^Falk/BOLD_IMAGE_run05/1.3.12.2.1107.5.2.43.66044.2023072016055674423574303.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR135/CAMRIS^Falk/FieldMap_PA_4/1.3.12.2.1107.5.2.43.66044.202307201612553599292788.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR135/CAMRIS^Falk/T2_1mm_SPACE/1.3.12.2.1107.5.2.43.66044.2023072016180429788393576.0.0.0.dicom.zip
#
# Participant 135 Complete
#
# -------------- Transferring: GR148 -------------
# Downloading tar
# Opening tar in memory as: <_io.BufferedReader name='working_data/GR148.tar'>
#
# makedirs --> /fmriDataRaw/fmri_data_raw/georemote/GR148/
# Extracting: scitran/falklab/geoscan/GR148/CAMRIS^Falk/localizer_multislice/1.3.12.2.1107.5.2.43.66044.2023081411223074174890625.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR148/CAMRIS^Falk/AAHead_Scout/1.3.12.2.1107.5.2.43.66044.2023081411233169496991426.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR148/CAMRIS^Falk/AAHead_Scout_MPR_sag/1.3.12.2.1107.5.2.43.66044.2023081411233537243292475.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR148/CAMRIS^Falk/AAHead_Scout_MPR_cor/1.3.12.2.1107.5.2.43.66044.2023081411233537288992481.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR148/CAMRIS^Falk/AAHead_Scout_MPR_tra/1.3.12.2.1107.5.2.43.66044.2023081411233537311592485.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR148/CAMRIS^Falk/MPRAGE_TI1100_ipat2/1.3.12.2.1107.5.2.43.66044.2023081411244461860192806.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR148/CAMRIS^Falk/BOLD_IMAGE_run01/1.3.12.2.1107.5.2.43.66044.2023081411314834496993968.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR148/CAMRIS^Falk/FieldMap_PA/1.3.12.2.1107.5.2.43.66044.2023081411395986839312453.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR148/CAMRIS^Falk/PhoenixZIPReport/1.3.12.2.1107.5.2.43.66044.30000023080917020206400000401.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR148/CAMRIS^Falk/BOLD_IMAGE_run02/1.3.12.2.1107.5.2.43.66044.2023081411402061698913018.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR148/CAMRIS^Falk/FieldMap_PA_1/1.3.12.2.1107.5.2.43.66044.2023081411473697729231503.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR148/CAMRIS^Falk/BOLD_IMAGE_run03/1.3.12.2.1107.5.2.43.66044.2023081411475773938632068.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR148/CAMRIS^Falk/FieldMap_PA_2/1.3.12.2.1107.5.2.43.66044.2023081411550227570650553.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR148/CAMRIS^Falk/BOLD_IMAGE_run04/1.3.12.2.1107.5.2.43.66044.2023081411552319793651118.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR148/CAMRIS^Falk/FieldMap_PA_3/1.3.12.2.1107.5.2.43.66044.2023081412023149009469603.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR148/CAMRIS^Falk/BOLD_IMAGE_run05/1.3.12.2.1107.5.2.43.66044.2023081412025221113170168.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR148/CAMRIS^Falk/FieldMap_PA_4/1.3.12.2.1107.5.2.43.66044.2023081412100476344788653.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR148/CAMRIS^Falk/T2_1mm_SPACE/1.3.12.2.1107.5.2.43.66044.2023081412145785661289450.0.0.0.dicom.zip
#
# Participant 148 Complete
#
# -------------- Transferring: GR178 -------------
# Downloading tar
# Opening tar in memory as: <_io.BufferedReader name='working_data/GR178.tar'>
#
# makedirs --> /fmriDataRaw/fmri_data_raw/georemote/GR178/
# Extracting: scitran/falklab/geoscan/GR178/unknown/localizer_multislice/1.3.12.2.1107.5.2.43.66044.2023082411254083534796016.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR178/unknown/AAHead_Scout/1.3.12.2.1107.5.2.43.66044.2023082411264194238696786.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR178/unknown/AAHead_Scout_MPR_sag/1.3.12.2.1107.5.2.43.66044.2023082411264561599497866.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR178/unknown/AAHead_Scout_MPR_cor/1.3.12.2.1107.5.2.43.66044.2023082411264561641997872.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR178/unknown/AAHead_Scout_MPR_tra/1.3.12.2.1107.5.2.43.66044.2023082411264561664597876.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR178/unknown/PhoenixZIPReport/1.3.12.2.1107.5.2.43.66044.30000023082118223845200000497.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR178/unknown/MPRAGE_TI1100_ipat2/1.3.12.2.1107.5.2.43.66044.2023082411291973855098197.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR178/unknown/BOLD_IMAGE_run01/1.3.12.2.1107.5.2.43.66044.2023082411361050846299365.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR178/unknown/FieldMap_PA/1.3.12.2.1107.5.2.43.66044.2023082411433853740566892.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR178/unknown/BOLD_IMAGE_run02/1.3.12.2.1107.5.2.43.66044.2023082411435598478467690.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR178/unknown/FieldMap_PA_1/1.3.12.2.1107.5.2.43.66044.2023082411514093090634958.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR178/unknown/BOLD_IMAGE_run03/1.3.12.2.1107.5.2.43.66044.2023082411515929819935756.0.0.0.dicom.zip
