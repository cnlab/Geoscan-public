# %% [markdown]
# # Transfer multiple participants
#
# This script allows you to loop through a list of participants.
#
# You'll probably want to use the test notebook (`Flywheel_Data_Transfer.ipynb`) first for one participants to create the credential config file and figure out the correct variable names.

# %%
import flywheel
import tarfile
import os
import time
import zipfile
from zipfile import ZipFile
import configparser

# %% [markdown]
# ## Define functions

# %%
def transfer_data (sub, in_prefix, out_prefix, in_project, out_project):
    ipID = in_prefix + sub
    opID = out_prefix + sub
    outpath = '/fmriDataRaw/fmri_data_raw/{PROJECT}'.format(PROJECT=out_project)
    
    if os.path.exists(os.path.join(outpath, opID)) == False:
        print('-------------- Transferring: {} -------------'.format(ipID))
        
        # download tar file
        session = fw.lookup('falklab/{proj}/{pid}'.format(proj=in_project,pid=ipID))
        print ('Downloading tar')
        fw.download_tar(session,'./working_data/{opID}.tar'.format(opID=opID))
        
        # open tar file
        with open("working_data/{opID}.tar".format(opID=opID), 'rb') as f: # <--- Flywheel download as Read Bytes
            print ('Opening tar in memory as:',f,'\n')
            tar_data = tarfile.open(fileobj=f, mode='r:') # <--- Unpack tar in memory
        
            # Create the directory if not exist
            output_dicom_dir = '{outpath}/{opID}/'.format(outpath=outpath,opID=opID)

            if not os.path.exists(os.path.dirname(output_dicom_dir)):
                try:
                    print('makedirs --> {}'.format(output_dicom_dir))
                    os.makedirs(os.path.dirname(output_dicom_dir))
                except:
                    print('oops! failed to create --> {}'.format(output_dicom_dir))     


            # Extract dicom files
            for member in tar_data.getmembers():
                if 'dicom.zip' in member.name:       # <--- Only extract files with 'dicom.zip' 
                    print('Extracting: {}\n'.format(member.name))

                    tfile = tar_data.extractfile(member.name)
                    dicom_zip = zipfile.ZipFile(tfile, mode='r')
                    dicom_zip.extractall(output_dicom_dir)

            print('Participant {} Complete\n'.format(sub))
        #tar_data.close()
    else:
        print('-------------- Skipping existing participant: {} -------------'.format(ipID))

# %% [markdown]
# ## Define variables
# * home_dir = home directory where the config file was created in the test notebook
# * in_project = project name on flywheel
# * out_project = desired output project name
# * subs = participant numbers minus the prefix (e.g. use 01 for bpp01)
# * in_prefix = project prefix listed on flywheel
# * out_prefix = desired project prefix

# %%
# home_dir = "/home/dcosme@asc.upenn.edu"
# in_project = 'bbprime'
# out_project = "bbprime"
# subs = ['21', '22', '23']
# in_prefix = 'bpp'
# out_prefix = 'BPP'

home_dir = "/home/bmuzekari@asc.upenn.edu"
in_project = 'geoscan'
out_project = "georemote"
subs = ['135','148','178','168','199','076','205','241','236','231','235','255','257','306','303']
in_prefix = 'GR'
out_prefix = 'GR'

# %% [markdown]
# ## Setup API

# %%
# add UPenn Flywheel api key to your config.ini
fw_cred = {}
config = configparser.ConfigParser()

config.read(home_dir + '/configs/config.ini') # <--- add your Twitter API tokens to this file!
for item,value in config['UPENN-FLYWHEEL'].items():
    fw_cred[item]=value

# read your API key
api = fw_cred['apikey']

# Create client using your API key
fw = flywheel.Client(api)

# print your flywheel information & confirm it works as expected
self = fw.get_current_user()
print('UPenn Flywheel User: %s %s (%s)' % 
      (self.firstname, self.lastname, self.email))
# Out:
# UPenn Flywheel User: Anthony Resnick (aresni@upenn.edu)

# %% [markdown]
# ## Loop through data

# %%
for sub in subs:
    transfer_data(sub, in_prefix, out_prefix, in_project, out_project)
# Out:
# -------------- Transferring: GR002 -------------
# Downloading tar
# Opening tar in memory as: <_io.BufferedReader name='working_data/GR002.tar'>
#
# makedirs --> /fmriDataRaw/fmri_data_raw/georemote/GR002/
# Extracting: scitran/falklab/geoscan/GR002/CAMRIS^Falk/localizer_multislice/1.3.12.2.1107.5.2.43.66044.2023022512215696846391273.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR002/CAMRIS^Falk/AAHead_Scout/1.3.12.2.1107.5.2.43.66044.2023022512225820850392015.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR002/CAMRIS^Falk/AAHead_Scout_MPR_sag/1.3.12.2.1107.5.2.43.66044.2023022512230196970993123.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR002/CAMRIS^Falk/AAHead_Scout_MPR_cor/1.3.12.2.1107.5.2.43.66044.2023022512230197013193129.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR002/CAMRIS^Falk/AAHead_Scout_MPR_tra/1.3.12.2.1107.5.2.43.66044.2023022512230197036093133.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR002/CAMRIS^Falk/PhoenixZIPReport/1.3.12.2.1107.5.2.43.66044.30000023022221520216700000400.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR002/CAMRIS^Falk/MPRAGE_TI1100_ipat2/1.3.12.2.1107.5.2.43.66044.2023022512253019959093454.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR002/CAMRIS^Falk/BOLD_IMAGE_run01/1.3.12.2.1107.5.2.43.66044.202302251230228245394616.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR002/CAMRIS^Falk/FieldMap_PA/1.3.12.2.1107.5.2.43.66044.2023022512382858651513101.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR002/CAMRIS^Falk/BOLD_IMAGE_run02/1.3.12.2.1107.5.2.43.66044.2023022512384952389313666.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR002/CAMRIS^Falk/FieldMap_PA_1/1.3.12.2.1107.5.2.43.66044.202302251246011653232151.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR002/CAMRIS^Falk/BOLD_IMAGE_run03/1.3.12.2.1107.5.2.43.66044.2023022512462183021032716.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR002/CAMRIS^Falk/FieldMap_PA_2/1.3.12.2.1107.5.2.43.66044.2023022512535795456851201.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR002/CAMRIS^Falk/BOLD_IMAGE_run04/1.3.12.2.1107.5.2.43.66044.2023022512584779151462313.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR002/CAMRIS^Falk/FieldMap_PA_3/1.3.12.2.1107.5.2.43.66044.2023022513053288611180798.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR002/CAMRIS^Falk/BOLD_IMAGE_run05/1.3.12.2.1107.5.2.43.66044.2023022513055390161281363.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR002/CAMRIS^Falk/FieldMap_PA_4/1.3.12.2.1107.5.2.43.66044.2023022513124739423099848.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR002/CAMRIS^Falk/T2_1mm_SPACE/1.3.12.2.1107.5.2.43.66044.2023022513180529713600662.0.0.0.dicom.zip
#
# Participant 002 Complete
#
# -------------- Transferring: GR099 -------------
# Downloading tar
# Opening tar in memory as: <_io.BufferedReader name='working_data/GR099.tar'>
#
# makedirs --> /fmriDataRaw/fmri_data_raw/georemote/GR099/
# Extracting: scitran/falklab/geoscan/GR099/CAMRIS^Falk/localizer_multislice/1.3.12.2.1107.5.2.43.66044.2023052511094791521124990.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR099/CAMRIS^Falk/AAHead_Scout/1.3.12.2.1107.5.2.43.66044.2023052511104935427425760.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR099/CAMRIS^Falk/AAHead_Scout_MPR_sag/1.3.12.2.1107.5.2.43.66044.2023052511105298197026840.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR099/CAMRIS^Falk/AAHead_Scout_MPR_cor/1.3.12.2.1107.5.2.43.66044.2023052511105298236126846.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR099/CAMRIS^Falk/AAHead_Scout_MPR_tra/1.3.12.2.1107.5.2.43.66044.2023052511105298259226850.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR099/CAMRIS^Falk/PhoenixZIPReport/1.3.12.2.1107.5.2.43.66044.30000023051913172416100000817.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR099/CAMRIS^Falk/MPRAGE_TI1100_ipat2/1.3.12.2.1107.5.2.43.66044.2023052511112752770827171.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR099/CAMRIS^Falk/BOLD_IMAGE_run01/1.3.12.2.1107.5.2.43.66044.2023052511183473411928333.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR099/CAMRIS^Falk/FieldMap_PA/1.3.12.2.1107.5.2.43.66044.2023052511252289290546818.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR099/CAMRIS^Falk/BOLD_IMAGE_run02/1.3.12.2.1107.5.2.43.66044.2023052511254381218947383.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR099/CAMRIS^Falk/FieldMap_PA_1/1.3.12.2.1107.5.2.43.66044.2023052511324845915365868.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR099/CAMRIS^Falk/BOLD_IMAGE_run03/1.3.12.2.1107.5.2.43.66044.2023052511330959136966433.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR099/CAMRIS^Falk/FieldMap_PA_2/1.3.12.2.1107.5.2.43.66044.2023052511401696148984918.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR099/CAMRIS^Falk/BOLD_IMAGE_run04/1.3.12.2.1107.5.2.43.66044.20230525114038613985483.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR099/CAMRIS^Falk/FieldMap_PA_3/1.3.12.2.1107.5.2.43.66044.2023052511491416001803968.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR099/CAMRIS^Falk/BOLD_IMAGE_run05/1.3.12.2.1107.5.2.43.66044.2023052511493613501104533.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR099/CAMRIS^Falk/FieldMap_PA_4/1.3.12.2.1107.5.2.43.66044.2023052511565880496123018.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR099/CAMRIS^Falk/T2_1mm_SPACE/1.3.12.2.1107.5.2.43.66044.2023052512015170221923807.0.0.0.dicom.zip
#
# Participant 099 Complete
#
# -------------- Transferring: GR092 -------------
# Downloading tar
# Opening tar in memory as: <_io.BufferedReader name='working_data/GR092.tar'>
#
# makedirs --> /fmriDataRaw/fmri_data_raw/georemote/GR092/
# Extracting: scitran/falklab/geoscan/GR092/CAMRIS^Falk/localizer_multislice/1.3.12.2.1107.5.2.43.66044.2023060713093926881577379.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR092/CAMRIS^Falk/PhoenixZIPReport/1.3.12.2.1107.5.2.43.66044.30000023060112574062500000533.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR092/CAMRIS^Falk/AAHead_Scout/1.3.12.2.1107.5.2.43.66044.2023060713104058329378152.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR092/CAMRIS^Falk/AAHead_Scout_MPR_sag/1.3.12.2.1107.5.2.43.66044.2023060713104416807079229.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR092/CAMRIS^Falk/AAHead_Scout_MPR_cor/1.3.12.2.1107.5.2.43.66044.2023060713104416850279235.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR092/CAMRIS^Falk/AAHead_Scout_MPR_tra/1.3.12.2.1107.5.2.43.66044.2023060713104416872079239.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR092/CAMRIS^Falk/MPRAGE_TI1100_ipat2/1.3.12.2.1107.5.2.43.66044.2023060713124249779879563.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR092/CAMRIS^Falk/BOLD_IMAGE_run01/1.3.12.2.1107.5.2.43.66044.2023060713174010430080725.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR092/CAMRIS^Falk/FieldMap_PA/1.3.12.2.1107.5.2.43.66044.202306071325417539599210.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR092/CAMRIS^Falk/BOLD_IMAGE_run02/1.3.12.2.1107.5.2.43.66044.2023060713260187053899775.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR092/CAMRIS^Falk/FieldMap_PA_1/1.3.12.2.1107.5.2.43.66044.2023060713331245254018260.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR092/CAMRIS^Falk/BOLD_IMAGE_run03/1.3.12.2.1107.5.2.43.66044.2023060713333362797218825.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR092/CAMRIS^Falk/FieldMap_PA_2/1.3.12.2.1107.5.2.43.66044.2023060713404752255637310.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR092/CAMRIS^Falk/BOLD_IMAGE_run04/1.3.12.2.1107.5.2.43.66044.2023060713410850892837875.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR092/CAMRIS^Falk/FieldMap_PA_3/1.3.12.2.1107.5.2.43.66044.2023060713482735549756360.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR092/CAMRIS^Falk/BOLD_IMAGE_run05/1.3.12.2.1107.5.2.43.66044.2023060713484837501456925.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR092/CAMRIS^Falk/FieldMap_PA_4/1.3.12.2.1107.5.2.43.66044.202306071356198585775410.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR092/CAMRIS^Falk/T2_1mm_SPACE/1.3.12.2.1107.5.2.43.66044.2023060714012993519976201.0.0.0.dicom.zip
# Participant 092 Complete
#
# -------------- Transferring: GR113 -------------
# Downloading tar
# Opening tar in memory as: <_io.BufferedReader name='working_data/GR113.tar'>
#
# makedirs --> /fmriDataRaw/fmri_data_raw/georemote/GR113/
# Extracting: scitran/falklab/geoscan/GR113/CAMRIS^Falk/localizer_multislice/1.3.12.2.1107.5.2.43.66044.2023061210563735899912988.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR113/CAMRIS^Falk/AAHead_Scout/1.3.12.2.1107.5.2.43.66044.2023061210573847031713740.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR113/CAMRIS^Falk/AAHead_Scout_MPR_sag/1.3.12.2.1107.5.2.43.66044.202306121057429852714838.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR113/CAMRIS^Falk/AAHead_Scout_MPR_cor/1.3.12.2.1107.5.2.43.66044.202306121057429890814844.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR113/CAMRIS^Falk/AAHead_Scout_MPR_tra/1.3.12.2.1107.5.2.43.66044.202306121057429913714848.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR113/CAMRIS^Falk/PhoenixZIPReport/1.3.12.2.1107.5.2.43.66044.30000023061213034802000000033.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR113/CAMRIS^Falk/MPRAGE_TI1100_ipat2/1.3.12.2.1107.5.2.43.66044.202306121058316961115169.0.0.0.dicom.zip
#
# Extracting: scitran/falklab/geoscan/GR113/CAMRIS^Falk/BOLD_IMAGE_run01/1.3.12.2.1107.5.2.43.66044.2