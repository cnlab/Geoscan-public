# %% [markdown]
# # DICOM-to-BIDS conversion using `heudiconv` and `singularity`
#
# * This notebook walks through the steps for doing DICOM to BIDS conversion using `heudiconv` with the Singularity image for a single participant to identify the correct parameters
#
#
# * For a new project the initial configuration steps will need to be completed to create the `heuristic.py` file. But this only needs to be done once and then it should be straight forward to run new participants.
#
# * There is a tutorial on using heudiconv:
#     - http://reproducibility.stanford.edu/bids-tutorial-series-part-2a/
#
#   that was used as a basis for this but required some tweaks.
#
#
# #### HISTORY
#
# * 9/9/21 dcosme - separated into two notebooks; this notebooks is to identify the parameters, the other creates jobs for each participant to convert
# * 4/1/20 mbod - initial setup for MURI DICOMS

# %% [markdown]
# ## Location of files
#
# 1. DICOMS for UPenn data are in:
#     ```
#     /fmriDataRaw/fmri_data_raw/{project}/
#
#     ```
#
#     * DICOMS (`.dcm` files) should match:
#     ```
#     /fmriDataRaw/fmri_data_raw/{project}/{subject}/{scan}/*.dcm
#     ```
#
#
# 2. BIDS files should be in  (may need to create these directories)
#     ```
#     /data00/projects/{project}/data/bids_data
#     ```
#
# 3. Config files for `heudiconv` will be in
#     ```
#     /data00/projects/{project}/scripts/BIDS/heudiconv
#     ```

# %%
raw_directory = '/fmriDataRaw/fmri_data_raw/geoscan/T2'
# !ls $raw_directory
# Out:
# BIDStest   GEO013_T2  GEO036_T2  GEO061_T2  GEO070_T2  GEO078_T2
# GEO004_T2  GEO015_T2  GEO037_T2  GEO064_T2  GEO071_T2  GS_pilotBM
# GEO006_T2  GEO021_T2  GEO047_T2  GEO067_T2  GEO073_T2  GSTEST_TX
# GEO010_T2  GEO033_T2  GEO053_T2  GEO068_T2  GEO074_T2

# %%
bids_directory = '/data00/projects/geoscan_v2/data/bids_data'
# !ls  $bids_directory
# Out:
# CHANGES			  sub-GEO033  sub-GEO071  sub-GS025
# dataset_description.json  sub-GEO036  sub-GEO073  sub-GS028
# derivatives		  sub-GEO037  sub-GEO074  sub-GS031
# derivatives_noSDC	  sub-GEO053  sub-GEO078  sub-GS032
# participants.json	  sub-GEO061  sub-GS005   task-image_bold.json
# participants.tsv	  sub-GEO064  sub-GS008   task-rest_bold.json
# README			  sub-GEO067  sub-GS017   task-retrans_bold.json
# sub-GEO015		  sub-GEO068  sub-GS022
# sub-GEO021		  sub-GEO070  sub-GS024

# %% [markdown]
# ### Setup

# %%
import pandas as pd

# %% [markdown]
# ## Create the configuration files for a new project
#
# * For a new project you need to run `heudiconv` in heuristic mode once on a representative participant (i.e. has all the possible scans for a subject in study) and it will generate:
#     - a TSV file called `dicominfo.tsv` that contains the details of each of the scans in the dataset
#     - a Python template file called `heuristic.py` that you edit to setup the dicom volumes to NIFTI mapping
#
#
# * To run `heudiconv` in heuristic mode with Singularity image, edit the cell below using the correct paths for your directory (replace {Project Name}). Use:
#     ```
#     !singularity run --cleanenv \
#         -B /data00/projects/{Project Name}/data/bids_data:/base  \
#         -B /fmriDataRaw/fmri_data_raw:/raw \
#         /data00/tools/singularity_images/heudiconv_0.8.0 \
#         -d /raw/{Project Name}/{subject}/*/*.dcm \
#         -o heudiconv/ -f convertall -s {subject} -c none --overwrite
#     ```
#      where
#      * `-B /data00/BIDS:/base` makes a file mapping for singularity to where the data should be written (i.e. `/data00/BIDS/{project...}`)
#      * `-B /fmriDataRaw/fmri_data_raw:/raw` maps the DICOM directory to singularity location `/raw`
#      * `/data00/tools/singularity_images/heudiconv_0.8.0` is the path to the `heudiconv` Singularity image you want to use. (On 4/22/20 that is version 0.8.0 - but this will change and we try to keep an updated version)
#      * `-d /raw/{Project Name}/{subject}/*/*.dcm` is the file matching template for finding DICOM files. Here `/raw` maps to `/fmriDataRaw/fmri_data_raw` so we are looking for files that end with `.dcm` in `/fmriDataRaw/fmri_data_raw/{Project Name}/{subject}/*/*.dcm` - where subject will be specified with the -s param, e.g. `MURI155`
#      * `-o /base/{Project Name}/heudiconv/` is the location for output files from `heudiconv` to be written
#      * `-f convertall` means include all dicom files and scans (i.e. not just one type like anatomical or ignore localizers etc)
#      * `-c none` puts it into heuristic mode. This option specifies which tool to use to do dicom2nifti conversion and will be changed once the configuration is set up.

# %%
sub = "GEO053"

# !singularity run --cleanenv \
    -B /data00/projects/geoscan_v2/data/bids_data:/base  \
    -B /fmriDataRaw/fmri_data_raw:/raw \
    /data00/tools/singularity_images/heudiconv_0.8.0 \
    -d /raw/geoscan/T3/{subject}_T3/*.dcm \
    -o heudiconv/ -ss t3 -f convertall -s 'GEO053' -c none --overwrite
# Out:
# INFO: Running heudiconv version 0.8.0 latest 0.11.3
# INFO: Need to process 1 study sessions
# INFO: PROCESSING STARTS: {'subject': 'GEO053', 'outdir': '/fmriNASTest/data00/projects/geoscan_v2/scripts/BIDS/heudiconv/', 'session': 't2'}
# INFO: Processing 2603 dicoms
# INFO: Analyzing 2603 dicoms
# INFO: Generated sequence info for 11 studies with 2603 entries total
# INFO: PROCESSING DONE: {'subject': 'GEO053', 'outdir': '/fmriNASTest/data00/projects/geoscan_v2/scripts/BIDS/heudiconv/', 'session': 't2'}

# %% [markdown]
# * The output from this run is in a hidden folder called .heudiconv

# %%
# !ls -a heudiconv/.heudiconv/GEO053/info
#more heudiconv/code/heuristic.py
# Out:
# .   dicominfo_ses-t2.tsv   GEO053_ses-t2.auto.txt  heuristic.py
# ..  filegroup_ses-t2.json  GEO053_ses-t2.edit.txt

# %% [markdown]
# * We can look at the `dicominfo.tsv` in Pandas

# %%
scan_df=pd.read_csv('heudiconv/.heudiconv/{sub}/info/dicominfo_ses-t2.tsv'.format(sub=sub), sep='\t')
scan_df
# Out:
#     total_files_till_now       example_dcm_file                   series_id  \
# 0                      9  001_000001_000001.dcm      1-localizer_multislice
# 1                    404  001_000002_000001.dcm          2-BOLD_IMAGE_run01
# 2                    799  001_000003_000001.dcm          3-BOLD_IMAGE_run02
# 3                   1194  001_000004_000001.dcm          4-BOLD_IMAGE_run03
# 4                   1589  001_000005_000001.dcm          5-BOLD_IMAGE_run04
# 5                   1984  001_000006_000001.dcm          6-BOLD_IMAGE_run05
# 6                   2160  001_000007_000001.dcm              7-T2_1mm_SPACE
# 7                   2320  001_000008_000001.dcm       8-MPRAGE_TI1100_ipat2
# 8                   2423  001_000009_000001.dcm  9-DSI_2mm_102dir_b4000_mb3
# 9                   2543  001_000010_000001.dcm                    10-B0map
# 10                  2603  001_000011_000001.dcm                    11-B0map
#
#    dcm_dir_name  series_files  unspecified  dim1  dim2  dim3  dim4  ...  \
# 0     GEO053_T2             9          NaN   512   512     9     1  ...
# 1     GEO053_T2           395          NaN    84    84    56   395  ...
# 2     GEO053_T2           395          NaN    84    84    56   395  ...
# 3     GEO053_T2           395          NaN    84    84    56   395  ...
# 4     GEO053_T2           395          NaN    84    84    56   395  ...
# 5     GEO053_T2           395          NaN    84    84    56   395  ...
# 6     GEO053_T2           176          NaN   256   256   176     1  ...
# 7     GEO053_T2           160          NaN   256   192   160     1  ...
# 8     GEO053_T2           103          NaN   106   106    78   103  ...
# 9     GEO053_T2           120          NaN    80    80   120     1  ...
# 10    GEO053_T2            60          NaN    80    80    60     1  ...
#
#     study_description  referring_physician_name        series_description  \
# 0         CAMRIS^Falk                       NaN      localizer_multislice
# 1         CAMRIS^Falk                       NaN          BOLD_IMAGE_run01
# 2         CAMRIS^Falk                       NaN          BOLD_IMAGE_run02
# 3         CAMRIS^Falk                       NaN          BOLD_IMAGE_run03
# 4         CAMRIS^Falk                       NaN          BOLD_IMAGE_run04
# 5         CAMRIS^Falk                       NaN          BOLD_IMAGE_run05
# 6         CAMRIS^Falk                       NaN              T2_1mm_SPACE
# 7         CAMRIS^Falk                       NaN       MPRAGE_TI1100_ipat2
# 8         CAMRIS^Falk                       NaN  DSI_2mm_102dir_b4000_mb3
# 9         CAMRIS^Falk                       NaN                     B0map
# 10        CAMRIS^Falk                       NaN                     B0map
#
#     sequence_name                                         image_type  \
# 0          *fl2d1         ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM')
# 1     epfid2d1_84  ('ORIGINAL', 'PRIMARY', 'M', 'MB', 'ND', 'NORM...
# 2     epfid2d1_84  ('ORIGINAL', 'PRIMARY', 'M', 'MB', 'ND', 'NORM...
# 3     epfid2d1_84  ('ORIGINAL', 'PRIMARY', 'M', 'MB', 'ND', 'NORM...
# 4     epfid2d1_84  ('ORIGINAL', 'PRIMARY', 'M', 'MB', 'ND', 'NORM...
# 5     epfid2d1_84  ('ORIGINAL', 'PRIMARY', 'M', 'MB', 'ND', 'NORM...
# 6      *spc_282ns         ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM')
# 7      *tfl3d1_16         ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM')
# 8         ep_b5#1  ('ORIGINAL', 'PRIMARY', 'DIFFUSION', 'NONE', '...
# 9         *fm2d2r         ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM')
# 10        *fm2d2r                 ('ORIGINAL', 'PRIMARY', 'P', 'ND')
#
#    accession_number patient_age  patient_sex      date  \
# 0              None        021Y            M  20170718
# 1              None        021Y            M  20170718
# 2              None        021Y            M  20170718
# 3              None        021Y            M  20170718
# 4              None        021Y            M  20170718
# 5              None        021Y            M  20170718
# 6              None        021Y            M  20170718
# 7              None        021Y            M  20170718
# 8              None        021Y            M  20170718
# 9              None        021Y            M  20170718
# 10             None        021Y            M  20170718
#
#                                            series_uid
# 0   1.3.12.2.1107.5.2.43.66044.2017071815455218508...
# 1   1.3.12.2.1107.5.2.43.66044.2017071815490857006...
# 2   1.3.12.2.1107.5.2.43.66044.2017071815564076680...
# 3   1.3.12.2.1107.5.2.43.66044.2017071816033238423...
# 4   1.3.12.2.1107.5.2.43.66044.2017071816110432425...
# 5   1.3.12.2.1107.5.2.43.66044.2017071816180216283...
# 6   1.3.12.2.1107.5.2.43.66044.2017071816292997914...
# 7   1.3.12.2.1107.5.2.43.66044.2017071816293695891...
# 8   1.3.12.2.1107.5.2.43.66044.2017071816330844848...
# 9   1.3.12.2.1107.5.2.43.66044.2017071816390779984...
# 10  1.3.12.2.1107.5.2.43.66044.2017071816390779985...
#
# [11 rows x 26 columns]

# %% [markdown]
# * The goal is to set up a mapping between values some of these fields and a BIDS compliant file
#
#
# * The most useful fields for this are the `series_id` or `series_description` and the 4 dimension fields.
#   * `dim4` is the number of volumes and using this can help when there is a partial (i.e. scan started and stopped quickly) scan before a complete one where the `series_id` will be the same.

# %%
scan_df[['series_id', 'series_description', 'dim1','dim2','dim3','dim4']]
# Out:
#                      series_id        series_description  dim1  dim2  dim3  \
# 0       1-localizer_multislice      localizer_multislice   512   512     9
# 1           2-BOLD_IMAGE_run01          BOLD_IMAGE_run01    84    84    56
# 2           3-BOLD_IMAGE_run02          BOLD_IMAGE_run02    84    84    56
# 3           4-BOLD_IMAGE_run03          BOLD_IMAGE_run03    84    84    56
# 4           5-BOLD_IMAGE_run04          BOLD_IMAGE_run04    84    84    56
# 5           6-BOLD_IMAGE_run05          BOLD_IMAGE_run05    84    84    56
# 6               7-T2_1mm_SPACE              T2_1mm_SPACE   256   256   176
# 7        8-MPRAGE_TI1100_ipat2       MPRAGE_TI1100_ipat2   256   192   160
# 8   9-DSI_2mm_102dir_b4000_mb3  DSI_2mm_102dir_b4000_mb3   106   106    78
# 9                     10-B0map                     B0map    80    80   120
# 10                    11-B0map                     B0map    80    80    60
#
#     dim4
# 0      1
# 1    395
# 2    395
# 3    395
# 4    395
# 5    395
# 6      1
# 7      1
# 8    103
# 9      1
# 10     1

# %% [markdown]
# * There is a Python file called `heuristic.py` that needs to be edited to set up the mappings between dicom files and these scan data and the location within the BIDS structure in the output folder.
#
#
# * The two things that need to be added to this files are:
#     1. __KEYS__ that provide a file template and mapping to where in the BIDS output a certain filetype should be written
#     2. __MATCHES__ are condition statements that match a scan using the fields in the dataframe above and map them to a specific key
#
#
#
# * __KEYS__
# Use the ‘create_key’ function to create keys inside of the ‘infotodict’ function. See how keys are created for the t1 scan, the different functional runs, and the field maps. These are put into a dictionary, and the values will be added using the conditional matching.
#
# ```python
#  t1w = create_key('sub-{subject}/anat/sub-{subject}_T1w')
#
#     func_read=create_key('sub-{subject}/func/sub-{subject}_task-read_run-{item:01d}_bold')
#     func_share=create_key('sub-{subject}/func/sub-{subject}_task-share_run-{item:01d}_bold')
#
#     fmap_AP=create_key('sub-{subject}/fmap/sub-{subject}_acq-{item:01d}_dir-AP_epi')
#
#
#     info = {
#             t1w: [],
#             func_read: [], func_share: [],
#             fmap_AP: []
#            }
#
# ```
#
# ![](img/heudiconv1.png)
#
#
# * __CONDITIONAL MATCHES__
# Now, using the information from the dicominfo.tsv, we will go through the series and put the scans only when they have the full number of scans.
# ```python
# if (s.dim1 == 256) and (s.dim2 == 192) and ('MPRAGE_TI1100_ipat2' in s.series_id):
#             info[t1w].append(s.series_id)
#
#         if (s.dim4 == 824 or s.dim4 == 813) and ('read' in s.series_id):
#             info[func_read].append(s.series_id)
#
#         if (s.dim4 == 865 or s.dim4 == 854 or s.dim4 == 568) and ('share' in s.series_id):
#             info[func_share].append(s.series_id)
#
#         if (s.dim4 == 3) and ('epi' in s.series_id):
#             info[fmap_AP].append(s.series_id)
# ```
# ![](img/heudiconv2.png)

# %% [markdown]
# * Once these are added to `heuristic.py` which we keep in:
#     ```
#     {Your Project}/scripts/BIDS/heudiconv/code
#     ```
#
#
# * and we delete the `.heudiconv` heuristic folder. Then we are ready to convert DICOM files to NIFTIs and set them up in a BIDS compliant structure!

# %%
rm -fr heudiconv/.heudiconv

# %%
# !singularity run --cleanenv \
    -B /data00/projects/geoscan_v2:/base  \
    -B /fmriDataRaw/fmri_data_raw:/raw \
    /data00/tools/singularity_images/heudiconv_0.8.0 \
    -d /raw/geoscan/T3/{subject}_T3/*.dcm \
    -o /base/data/bids_data/ \
    -f /base/scripts/BIDS/heudiconv/code/heuristic.py -ss t3 -s 'GEO053'  -c dcm2niix -b --overwrite
# Out:
# INFO: Running heudiconv version 0.8.0 latest 0.11.3
# INFO: Need to process 1 study sessions
# INFO: PROCESSING STARTS: {'subject': 'GEO053', 'outdir': '/base/data/bids_data/', 'session': 't3'}
# INFO: Processing 3010 dicoms
# INFO: Analyzing 3010 dicoms
# INFO: Generated sequence info for 13 studies with 3010 entries total
# INFO: Doing conversion using dcm2niix
# INFO: Converting /base/data/bids_data/sub-GEO053/ses-t3/anat/sub-GEO053_ses-t3_T1w (160 DICOMs) -> /base/data/bids_data/sub-GEO053/ses-t3/anat . Converter: dcm2niix . Output types: ('nii.gz',)
# 220613-16:03:07,677 nipype.utils INFO:
# 	 Running nipype version 1.4.2 (latest: 1.8.1)
# INFO: Running nipype version 1.4.2 (latest: 1.8.1)
# 220613-16:03:07,683 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niixgnxm0lkd/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niixgnxm0lkd/convert".
# 220613-16:03:07,747 nipype.workflow INFO:
# 	 [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO053/ses-t3/anat/sub-GEO053_ses-t3_T1w -o . -s n -v n /tmp/dcm2niixgnxm0lkd/convert
# INFO: [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO053/ses-t3/anat/sub-GEO053_ses-t3_T1w -o . -s n -v n /tmp/dcm2niixgnxm0lkd/convert
# 220613-16:03:08,356 nipype.interface INFO:
# 	 stdout 2022-06-13T16:03:08.356691:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# INFO: stdout 2022-06-13T16:03:08.356691:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# 220613-16:03:08,357 nipype.interface INFO:
# 	 stdout 2022-06-13T16:03:08.356691:Found 160 DICOM file(s)
# INFO: stdout 2022-06-13T16:03:08.356691:Found 160 DICOM file(s)
# 220613-16:03:08,357 nipype.interface INFO:
# 	 stdout 2022-06-13T16:03:08.356691:Convert 160 DICOM as ./base/data/bids_data/sub-GEO053/ses-t3/anat/sub-GEO053_ses-t3_T1w (192x256x160x1)
# INFO: stdout 2022-06-13T16:03:08.356691:Convert 160 DICOM as ./base/data/bids_data/sub-GEO053/ses-t3/anat/sub-GEO053_ses-t3_T1w (192x256x160x1)
# 220613-16:03:08,651 nipype.interface INFO:
# 	 stdout 2022-06-13T16:03:08.651132:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GEO053/ses-t3/anat/sub-GEO053_ses-t3_T1w.nii"
# INFO: stdout 2022-06-13T16:03:08.651132:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GEO053/ses-t3/anat/sub-GEO053_ses-t3_T1w.nii"
# 220613-16:03:08,651 nipype.interface INFO:
# 	 stdout 2022-06-13T16:03:08.651132:Conversion required 0.760877 seconds (0.269483 for core code).
# INFO: stdout 2022-06-13T16:03:08.651132:Conversion required 0.760877 seconds (0.269483 for core code).
# 220613-16:03:08,684 nipype.workflow INFO:
# 	 [Node] Finished "convert".
# INFO: [Node] Finished "convert".
# WARNING: Failed to find task field in /base/data/bids_data/sub-GEO053/ses-t3/anat/sub-GEO053_ses-t3_T1w.json.
# 220613-16:03:09,824 nipype.workflow INFO:
# 	 [Node] Setting-up "embedder" in "/tmp/embedmetagco5i68v/embedder".
# INFO: [Node] Setting-up "embedder" in "/tmp/embedmetagco5i68v/embedder".
# 220613-16:03:09,901 nipype.workflow INFO:
# 	 [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# INFO: [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# 220613-16:03:14,812 nipype.workflow WARNING:
# 	 Storing result file without outputs
# WARNING: Storing result file without outputs
# 220613-16:03:14,813 nipype.workflow WARNING:
# 	 [Node] Error on "embedder" (/tmp/embedmetagco5i68v/embedder)
# WARNING: [Node] Error on "embedder" (/tmp/embedmetagco5i68v/embedder)
# ERROR: Embedding failed: 'NoneType' object is not subscriptable
# INFO: Post-treating /base/data/bids_data/sub-GEO053/ses-t3/anat/sub-GEO053_ses-t3_T1w.json file
# INFO: Converting /base/data/bids_data/sub-GEO053/ses-t3/anat/sub-GEO053_ses-t3_T2w (176 DICOMs) -> /base/data/bids_data/sub-GEO053/ses-t3/anat . Converter: dcm2niix . Output types: ('nii.gz',)
# 220613-16:03:14,927 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niix6hpk0mlb/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niix6hpk0mlb/convert".
# 220613-16:03:14,993 nipype.workflow INFO:
# 	 [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO053/ses-t3/anat/sub-GEO053_ses-t3_T2w -o . -s n -v n /tmp/dcm2niix6hpk0mlb/convert
# INFO: [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO053/ses-t3/anat/sub-GEO053_ses-t3_T2w -o . -s n -v n /tmp/dcm2niix6hpk0mlb/convert
# 220613-16:03:15,541 nipype.interface INFO:
# 	 stdout 2022-06-13T16:03:15.541415:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# INFO: stdout 2022-06-13T16:03:15.541415:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# 220613-16:03:15,541 nipype.interface INFO:
# 	 stdout 2022-06-13T16:03:15.541415:Found 176 DICOM file(s)
# INFO: stdout 2022-06-13T16:03:15.541415:Found 176 DICOM file(s)
# 220613-16:03:15,541 nipype.interface INFO:
# 	 stdout 2022-06-13T16:03:15.541415:Convert 176 DICOM as ./base/data/bids_data/sub-GEO053/ses-t3/anat/sub-GEO053_ses-t3_T2w (256x256x176x1)
# INFO: stdout 2022-06-13T16:03:15.541415:Convert 176 DICOM as ./base/data/bids_data/sub-GEO053/ses-t3/anat/sub-GEO053_ses-t3_T2w (256x256x176x1)
# 220613-16:03:15,983 nipype.interface INFO:
# 	 stdout 2022-06-13T16:03:15.983549:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GEO053/ses-t3/anat/sub-GEO053_ses-t3_T2w.nii"
# INFO: stdout 2022-06-13T16:03:15.983549:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GEO053/ses-t3/anat/sub-GEO053_ses-t3_T2w.nii"
# 220613-16:03:15,983 nipype.interface INFO:
# 	 stdout 2022-06-13T16:03:15.983549:Conversion required 0.956988 seconds (0.349525 for core code).
# INFO: stdout 2022-06-13T16:03:15.983549:Conversion required 0.956988 seconds (0.349525 for core code).
# 220613-16:03:16,27 nipype.workflow INFO:
# 	 [Node] Finished "convert".
# INFO: [Node] Finished "convert".
# WARNING: Failed to find task field in /base/data/bids_data/sub-GEO053/ses-t3/anat/sub-GEO053_ses-t3_T2w.json.
# 220613-16:03:16,717 nipype.workflow INFO:
# 	 [Node] Setting-up "embedder" in "/tmp/embedmeta4h55gtk1/embedder".
# INFO: [Node] Setting-up "embedder" in "/tmp/embedmeta4h55gtk1/embedder".
# 220613-16:03:16,741 nipype.workflow INFO:
# 	 [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# INFO: [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# 220613-16:03:22,166 nipype.workflow WARNING:
# 	 Storing result file without outputs
# WARNING: Storing result file without outputs
# 220613-16:03:22,167 nipype.workflow WARNING:
# 	 [Node] Error on "embedder" (/tmp/embedmeta4h55gtk1/embedder)
# WARNING: [Node] Error on "embedder" (/tmp/embedmeta4h55gtk1/embedder)
# ERROR: Embedding failed: 'NoneType' object is not subscriptable
# INFO: Post-treating /base/data/bids_data/sub-GEO053/ses-t3/anat/sub-GEO053_ses-t3_T2w.json file
# INFO: Converting /base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-image_run-1_bold (395 DICOMs) -> /base/data/bids_data/sub-GEO053/ses-t3/func . Converter: dcm2niix . Output types: ('nii.gz',)
# 220613-16:03:22,395 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niixuuv2dgdw/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niixuuv2dgdw/convert".
# 220613-16:03:22,544 nipype.workflow INFO:
# 	 [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-image_run-1_bold -o . -s n -v n /tmp/dcm2niixuuv2dgdw/convert
# INFO: [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-image_run-1_bold -o . -s n -v n /tmp/dcm2niixuuv2dgdw/convert
# 220613-16:03:24,882 nipype.interface INFO:
# 	 stdout 2022-06-13T16:03:24.881959:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# INFO: stdout 2022-06-13T16:03:24.881959:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# 220613-16:03:24,882 nipype.interface INFO:
# 	 stdout 2022-06-13T16:03:24.881959:Found 395 DICOM file(s)
# INFO: stdout 2022-06-13T16:03:24.881959:Found 395 DICOM file(s)
# 220613-16:03:24,882 nipype.interface INFO:
# 	 stdout 2022-06-13T16:03:24.881959:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# INFO: stdout 2022-06-13T16:03:24.881959:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# 220613-16:03:24,882 nipype.interface INFO:
# 	 stdout 2022-06-13T16:03:24.881959:Convert 395 DICOM as ./base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-image_run-1_bold (84x84x56x395)
# INFO: stdout 2022-06-13T16:03:24.881959:Convert 395 DICOM as ./base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-image_run-1_bold (84x84x56x395)
# 220613-16:03:28,63 nipype.interface INFO:
# 	 stdout 2022-06-13T16:03:28.063626:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-image_run-1_bold.nii"
# INFO: stdout 2022-06-13T16:03:28.063626:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-image_run-1_bold.nii"
# 220613-16:03:28,63 nipype.interface INFO:
# 	 stdout 2022-06-13T16:03:28.063626:Conversion required 5.488265 seconds (1.815476 for core code).
# INFO: stdout 2022-06-13T16:03:28.063626:Conversion required 5.488265 seconds (1.815476 for core code).
# 220613-16:03:28,117 nipype.workflow INFO:
# 	 [Node] Finished "convert".
# INFO: [Node] Finished "convert".
# 220613-16:03:30,132 nipype.workflow INFO:
# 	 [Node] Setting-up "embedder" in "/tmp/embedmetag5viyjl6/embedder".
# INFO: [Node] Setting-up "embedder" in "/tmp/embedmetag5viyjl6/embedder".
# 220613-16:03:30,183 nipype.workflow INFO:
# 	 [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# INFO: [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# 220613-16:03:55,139 nipype.workflow WARNING:
# 	 Storing result file without outputs
# WARNING: Storing result file without outputs
# 220613-16:03:55,141 nipype.workflow WARNING:
# 	 [Node] Error on "embedder" (/tmp/embedmetag5viyjl6/embedder)
# WARNING: [Node] Error on "embedder" (/tmp/embedmetag5viyjl6/embedder)
# ERROR: Embedding failed: 'NoneType' object is not subscriptable
# INFO: Post-treating /base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-image_run-1_bold.json file
# INFO: Converting /base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-image_run-2_bold (395 DICOMs) -> /base/data/bids_data/sub-GEO053/ses-t3/func . Converter: dcm2niix . Output types: ('nii.gz',)
# 220613-16:03:57,115 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niix1aed8tt2/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niix1aed8tt2/convert".
# 220613-16:03:57,261 nipype.workflow INFO:
# 	 [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-image_run-2_bold -o . -s n -v n /tmp/dcm2niix1aed8tt2/convert
# INFO: [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-image_run-2_bold -o . -s n -v n /tmp/dcm2niix1aed8tt2/convert
# 220613-16:03:59,665 nipype.interface INFO:
# 	 stdout 2022-06-13T16:03:59.665672:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# INFO: stdout 2022-06-13T16:03:59.665672:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# 220613-16:03:59,666 nipype.interface INFO:
# 	 stdout 2022-06-13T16:03:59.665672:Found 395 DICOM file(s)
# INFO: stdout 2022-06-13T16:03:59.665672:Found 395 DICOM file(s)
# 220613-16:03:59,666 nipype.interface INFO:
# 	 stdout 2022-06-13T16:03:59.665672:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# INFO: stdout 2022-06-13T16:03:59.665672:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# 220613-16:03:59,666 nipype.interface INFO:
# 	 stdout 2022-06-13T16:03:59.665672:Convert 395 DICOM as ./base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-image_run-2_bold (84x84x56x395)
# INFO: stdout 2022-06-13T16:03:59.665672:Convert 395 DICOM as ./base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-image_run-2_bold (84x84x56x395)
# 220613-16:04:02,884 nipype.interface INFO:
# 	 stdout 2022-06-13T16:04:02.884664:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-image_run-2_bold.nii"
# INFO: stdout 2022-06-13T16:04:02.884664:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-image_run-2_bold.nii"
# 220613-16:04:02,884 nipype.interface INFO:
# 	 stdout 2022-06-13T16:04:02.884664:Conversion required 5.482525 seconds (1.781949 for core code).
# INFO: stdout 2022-06-13T16:04:02.884664:Conversion required 5.482525 seconds (1.781949 for core code).
# 220613-16:04:02,964 nipype.workflow INFO:
# 	 [Node] Finished "convert".
# INFO: [Node] Finished "convert".
# 220613-16:04:04,521 nipype.workflow INFO:
# 	 [Node] Setting-up "embedder" in "/tmp/embedmeta9lts5vxf/embedder".
# INFO: [Node] Setting-up "embedder" in "/tmp/embedmeta9lts5vxf/embedder".
# 220613-16:04:04,568 nipype.workflow INFO:
# 	 [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# INFO: [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# 220613-16:04:29,431 nipype.workflow WARNING:
# 	 Storing result file without outputs
# WARNING: Storing result file without outputs
# 220613-16:04:29,433 nipype.workflow WARNING:
# 	 [Node] Error on "embedder" (/tmp/embedmeta9lts5vxf/embedder)
# WARNING: [Node] Error on "embedder" (/tmp/embedmeta9lts5vxf/embedder)
# ERROR: Embedding failed: 'NoneType' object is not subscriptable
# INFO: Post-treating /base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-image_run-2_bold.json file
# INFO: Converting /base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-image_run-3_bold (395 DICOMs) -> /base/data/bids_data/sub-GEO053/ses-t3/func . Converter: dcm2niix . Output types: ('nii.gz',)
# 220613-16:04:31,725 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niixw_doczq6/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niixw_doczq6/convert".
# 220613-16:04:31,866 nipype.workflow INFO:
# 	 [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-image_run-3_bold -o . -s n -v n /tmp/dcm2niixw_doczq6/convert
# INFO: [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-image_run-3_bold -o . -s n -v n /tmp/dcm2niixw_doczq6/convert
# 220613-16:04:34,220 nipype.interface INFO:
# 	 stdout 2022-06-13T16:04:34.220210:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# INFO: stdout 2022-06-13T16:04:34.220210:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# 220613-16:04:34,220 nipype.interface INFO:
# 	 stdout 2022-06-13T16:04:34.220210:Found 395 DICOM file(s)
# INFO: stdout 2022-06-13T16:04:34.220210:Found 395 DICOM file(s)
# 220613-16:04:34,220 nipype.interface INFO:
# 	 stdout 2022-06-13T16:04:34.220210:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# INFO: stdout 2022-06-13T16:04:34.220210:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# 220613-16:04:34,220 nipype.interface INFO:
# 	 stdout 2022-06-13T16:04:34.220210:Convert 395 DICOM as ./base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-image_run-3_bold (84x84x56x395)
# INFO: stdout 2022-06-13T16:04:34.220210:Convert 395 DICOM as ./base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-image_run-3_bold (84x84x56x395)
# 220613-16:04:37,303 nipype.interface INFO:
# 	 stdout 2022-06-13T16:04:37.303650:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-image_run-3_bold.nii"
# INFO: stdout 2022-06-13T16:04:37.303650:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-image_run-3_bold.nii"
# 220613-16:04:37,303 nipype.interface INFO:
# 	 stdout 2022-06-13T16:04:37.303650:Conversion required 5.311061 seconds (1.743029 for core code).
# INFO: stdout 2022-06-13T16:04:37.303650:Conversion required 5.311061 seconds (1.743029 for core code).
# 220613-16:04:37,383 nipype.workflow INFO:
# 	 [Node] Finished "convert".
# INFO: [Node] Finished "convert".
# 220613-16:04:39,49 nipype.workflow INFO:
# 	 [Node] Setting-up "embedder" in "/tmp/embedmetaamvbbipx/embedder".
# INFO: [Node] Setting-up "embedder" in "/tmp/embedmetaamvbbipx/embedder".
# 220613-16:04:39,88 nipype.workflow INFO:
# 	 [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# INFO: [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# 220613-16:05:04,45 nipype.workflow WARNING:
# 	 Storing result file without outputs
# WARNING: Storing result file without outputs
# 220613-16:05:04,47 nipype.workflow WARNING:
# 	 [Node] Error on "embedder" (/tmp/embedmetaamvbbipx/embedder)
# WARNING: [Node] Error on "embedder" (/tmp/embedmetaamvbbipx/embedder)
# ERROR: Embedding failed: 'NoneType' object is not subscriptable
# INFO: Post-treating /base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-image_run-3_bold.json file
# INFO: Converting /base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-image_run-4_bold (395 DICOMs) -> /base/data/bids_data/sub-GEO053/ses-t3/func . Converter: dcm2niix . Output types: ('nii.gz',)
# 220613-16:05:06,75 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niixin2yd2__/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niixin2yd2__/convert".
# 220613-16:05:06,219 nipype.workflow INFO:
# 	 [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-image_run-4_bold -o . -s n -v n /tmp/dcm2niixin2yd2__/convert
# INFO: [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-image_run-4_bold -o . -s n -v n /tmp/dcm2niixin2yd2__/convert
# 220613-16:05:08,619 nipype.interface INFO:
# 	 stdout 2022-06-13T16:05:08.619339:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# INFO: stdout 2022-06-13T16:05:08.619339:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# 220613-16:05:08,619 nipype.interface INFO:
# 	 stdout 2022-06-13T16:05:08.619339:Found 395 DICOM file(s)
# INFO: stdout 2022-06-13T16:05:08.619339:Found 395 DICOM file(s)
# 220613-16:05:08,619 nipype.interface INFO:
# 	 stdout 2022-06-13T16:05:08.619339:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# INFO: stdout 2022-06-13T16:05:08.619339:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# 220613-16:05:08,619 nipype.interface INFO:
# 	 stdout 2022-06-13T16:05:08.619339:Convert 395 DICOM as ./base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-image_run-4_bold (84x84x56x395)
# INFO: stdout 2022-06-13T16:05:08.619339:Convert 395 DICOM as ./base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-image_run-4_bold (84x84x56x395)
# 220613-16:05:11,879 nipype.interface INFO:
# 	 stdout 2022-06-13T16:05:11.879654:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-image_run-4_bold.nii"
# INFO: stdout 2022-06-13T16:05:11.879654:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-image_run-4_bold.nii"
# 220613-16:05:11,879 nipype.interface INFO:
# 	 stdout 2022-06-13T16:05:11.879654:Conversion required 5.530547 seconds (1.743259 for core code).
# INFO: stdout 2022-06-13T16:05:11.879654:Conversion required 5.530547 seconds (1.743259 for core code).
# 220613-16:05:11,955 nipype.workflow INFO:
# 	 [Node] Finished "convert".
# INFO: [Node] Finished "convert".
# 220613-16:05:13,458 nipype.workflow INFO:
# 	 [Node] Setting-up "embedder" in "/tmp/embedmetajqq5mfav/embedder".
# INFO: [Node] Setting-up "embedder" in "/tmp/embedmetajqq5mfav/embedder".
# 220613-16:05:13,529 nipype.workflow INFO:
# 	 [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# INFO: [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# 220613-16:05:38,81 nipype.workflow WARNING:
# 	 Storing result file without outputs
# WARNING: Storing result file without outputs
# 220613-16:05:38,84 nipype.workflow WARNING:
# 	 [Node] Error on "embedder" (/tmp/embedmetajqq5mfav/embedder)
# WARNING: [Node] Error on "embedder" (/tmp/embedmetajqq5mfav/embedder)
# ERROR: Embedding failed: 'NoneType' object is not subscriptable
# INFO: Post-treating /base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-image_run-4_bold.json file
# INFO: Converting /base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-image_run-5_bold (395 DICOMs) -> /base/data/bids_data/sub-GEO053/ses-t3/func . Converter: dcm2niix . Output types: ('nii.gz',)
# 220613-16:05:40,383 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niix437t8eyi/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niix437t8eyi/convert".
# 220613-16:05:40,535 nipype.workflow INFO:
# 	 [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-image_run-5_bold -o . -s n -v n /tmp/dcm2niix437t8eyi/convert
# INFO: [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-image_run-5_bold -o . -s n -v n /tmp/dcm2niix437t8eyi/convert
# 220613-16:05:42,942 nipype.interface INFO:
# 	 stdout 2022-06-13T16:05:42.942674:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# INFO: stdout 2022-06-13T16:05:42.942674:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# 220613-16:05:42,943 nipype.interface INFO:
# 	 stdout 2022-06-13T16:05:42.942674:Found 395 DICOM file(s)
# INFO: stdout 2022-06-13T16:05:42.942674:Found 395 DICOM file(s)
# 220613-16:05:42,943 nipype.interface INFO:
# 	 stdout 2022-06-13T16:05:42.942674:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# INFO: stdout 2022-06-13T16:05:42.942674:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# 220613-16:05:42,943 nipype.interface INFO:
# 	 stdout 2022-06-13T16:05:42.942674:Convert 395 DICOM as ./base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-image_run-5_bold (84x84x56x395)
# INFO: stdout 2022-06-13T16:05:42.942674:Convert 395 DICOM as ./base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-image_run-5_bold (84x84x56x395)
# 220613-16:05:46,25 nipype.interface INFO:
# 	 stdout 2022-06-13T16:05:46.025660:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-image_run-5_bold.nii"
# INFO: stdout 2022-06-13T16:05:46.025660:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-image_run-5_bold.nii"
# 220613-16:05:46,26 nipype.interface INFO:
# 	 stdout 2022-06-13T16:05:46.025660:Conversion required 5.356948 seconds (1.819178 for core code).
# INFO: stdout 2022-06-13T16:05:46.025660:Conversion required 5.356948 seconds (1.819178 for core code).
# 220613-16:05:46,107 nipype.workflow INFO:
# 	 [Node] Finished "convert".
# INFO: [Node] Finished "convert".
# 220613-16:05:48,103 nipype.workflow INFO:
# 	 [Node] Setting-up "embedder" in "/tmp/embedmetalc0tb7gi/embedder".
# INFO: [Node] Setting-up "embedder" in "/tmp/embedmetalc0tb7gi/embedder".
# 220613-16:05:48,148 nipype.workflow INFO:
# 	 [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# INFO: [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# 220613-16:06:13,764 nipype.workflow WARNING:
# 	 Storing result file without outputs
# WARNING: Storing result file without outputs
# 220613-16:06:13,766 nipype.workflow WARNING:
# 	 [Node] Error on "embedder" (/tmp/embedmetalc0tb7gi/embedder)
# WARNING: [Node] Error on "embedder" (/tmp/embedmetalc0tb7gi/embedder)
# ERROR: Embedding failed: 'NoneType' object is not subscriptable
# INFO: Post-treating /base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-image_run-5_bold.json file
# INFO: Converting /base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-retrans_run-1_bold (24 DICOMs) -> /base/data/bids_data/sub-GEO053/ses-t3/func . Converter: dcm2niix . Output types: ('nii.gz',)
# 220613-16:06:14,151 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niixd7sw_z3a/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niixd7sw_z3a/convert".
# 220613-16:06:14,164 nipype.workflow INFO:
# 	 [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-retrans_run-1_bold -o . -s n -v n /tmp/dcm2niixd7sw_z3a/convert
# INFO: [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-retrans_run-1_bold -o . -s n -v n /tmp/dcm2niixd7sw_z3a/convert
# 220613-16:06:14,453 nipype.interface INFO:
# 	 stdout 2022-06-13T16:06:14.453031:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# INFO: stdout 2022-06-13T16:06:14.453031:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# 220613-16:06:14,453 nipype.interface INFO:
# 	 stdout 2022-06-13T16:06:14.453031:Found 24 DICOM file(s)
# INFO: stdout 2022-06-13T16:06:14.453031:Found 24 DICOM file(s)
# 220613-16:06:14,453 nipype.interface INFO:
# 	 stdout 2022-06-13T16:06:14.453031:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# INFO: stdout 2022-06-13T16:06:14.453031:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# 220613-16:06:14,453 nipype.interface INFO:
# 	 stdout 2022-06-13T16:06:14.453031:Convert 24 DICOM as ./base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-retrans_run-1_bold (84x84x56x24)
# INFO: stdout 2022-06-13T16:06:14.453031:Convert 24 DICOM as ./base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-retrans_run-1_bold (84x84x56x24)
# 220613-16:06:14,684 nipype.interface INFO:
# 	 stdout 2022-06-13T16:06:14.684783:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-retrans_run-1_bold.nii"
# INFO: stdout 2022-06-13T16:06:14.684783:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-retrans_run-1_bold.nii"
# 220613-16:06:14,685 nipype.interface INFO:
# 	 stdout 2022-06-13T16:06:14.684783:Conversion required 0.393670 seconds (0.130875 for core code).
# INFO: stdout 2022-06-13T16:06:14.684783:Conversion required 0.393670 seconds (0.130875 for core code).
# 220613-16:06:14,746 nipype.workflow INFO:
# 	 [Node] Finished "convert".
# INFO: [Node] Finished "convert".
# 220613-16:06:15,394 nipype.workflow INFO:
# 	 [Node] Setting-up "embedder" in "/tmp/embedmeta2st4jq0n/embedder".
# INFO: [Node] Setting-up "embedder" in "/tmp/embedmeta2st4jq0n/embedder".
# 220613-16:06:15,409 nipype.workflow INFO:
# 	 [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# INFO: [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# 220613-16:06:16,965 nipype.workflow WARNING:
# 	 Storing result file without outputs
# WARNING: Storing result file without outputs
# 220613-16:06:16,966 nipype.workflow WARNING:
# 	 [Node] Error on "embedder" (/tmp/embedmeta2st4jq0n/embedder)
# WARNING: [Node] Error on "embedder" (/tmp/embedmeta2st4jq0n/embedder)
# ERROR: Embedding failed: 'NoneType' object is not subscriptable
# INFO: Post-treating /base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-retrans_run-1_bold.json file
# INFO: Converting /base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-retrans_run-2_bold (22 DICOMs) -> /base/data/bids_data/sub-GEO053/ses-t3/func . Converter: dcm2niix . Output types: ('nii.gz',)
# 220613-16:06:17,152 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niixjs4hnwur/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niixjs4hnwur/convert".
# 220613-16:06:17,169 nipype.workflow INFO:
# 	 [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-retrans_run-2_bold -o . -s n -v n /tmp/dcm2niixjs4hnwur/convert
# INFO: [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-retrans_run-2_bold -o . -s n -v n /tmp/dcm2niixjs4hnwur/convert
# 220613-16:06:17,429 nipype.interface INFO:
# 	 stdout 2022-06-13T16:06:17.429812:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# INFO: stdout 2022-06-13T16:06:17.429812:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# 220613-16:06:17,430 nipype.interface INFO:
# 	 stdout 2022-06-13T16:06:17.429812:Found 22 DICOM file(s)
# INFO: stdout 2022-06-13T16:06:17.429812:Found 22 DICOM file(s)
# 220613-16:06:17,430 nipype.interface INFO:
# 	 stdout 2022-06-13T16:06:17.429812:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# INFO: stdout 2022-06-13T16:06:17.429812:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# 220613-16:06:17,430 nipype.interface INFO:
# 	 stdout 2022-06-13T16:06:17.429812:Convert 22 DICOM as ./base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-retrans_run-2_bold (84x84x56x22)
# INFO: stdout 2022-06-13T16:06:17.429812:Convert 22 DICOM as ./base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-retrans_run-2_bold (84x84x56x22)
# 220613-16:06:17,655 nipype.interface INFO:
# 	 stdout 2022-06-13T16:06:17.655317:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-retrans_run-2_bold.nii"
# INFO: stdout 2022-06-13T16:06:17.655317:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-retrans_run-2_bold.nii"
# 220613-16:06:17,655 nipype.interface INFO:
# 	 stdout 2022-06-13T16:06:17.655317:Conversion required 0.376911 seconds (0.122840 for core code).
# INFO: stdout 2022-06-13T16:06:17.655317:Conversion required 0.376911 seconds (0.122840 for core code).
# 220613-16:06:17,688 nipype.workflow INFO:
# 	 [Node] Finished "convert".
# INFO: [Node] Finished "convert".
# 220613-16:06:19,53 nipype.workflow INFO:
# 	 [Node] Setting-up "embedder" in "/tmp/embedmetahj8uf22o/embedder".
# INFO: [Node] Setting-up "embedder" in "/tmp/embedmetahj8uf22o/embedder".
# 220613-16:06:19,78 nipype.workflow INFO:
# 	 [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# INFO: [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# 220613-16:06:20,504 nipype.workflow WARNING:
# 	 Storing result file without outputs
# WARNING: Storing result file without outputs
# 220613-16:06:20,504 nipype.workflow WARNING:
# 	 [Node] Error on "embedder" (/tmp/embedmetahj8uf22o/embedder)
# WARNING: [Node] Error on "embedder" (/tmp/embedmetahj8uf22o/embedder)
# ERROR: Embedding failed: 'NoneType' object is not subscriptable
# INFO: Post-treating /base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-retrans_run-2_bold.json file
# INFO: Converting /base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-retrans_run-3_bold (464 DICOMs) -> /base/data/bids_data/sub-GEO053/ses-t3/func . Converter: dcm2niix . Output types: ('nii.gz',)
# 220613-16:06:22,869 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niix93aq63nw/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niix93aq63nw/convert".
# 220613-16:06:23,33 nipype.workflow INFO:
# 	 [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-retrans_run-3_bold -o . -s n -v n /tmp/dcm2niix93aq63nw/convert
# INFO: [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-retrans_run-3_bold -o . -s n -v n /tmp/dcm2niix93aq63nw/convert
# 220613-16:06:25,866 nipype.interface INFO:
# 	 stdout 2022-06-13T16:06:25.866669:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# INFO: stdout 2022-06-13T16:06:25.866669:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# 220613-16:06:25,867 nipype.interface INFO:
# 	 stdout 2022-06-13T16:06:25.866669:Found 464 DICOM file(s)
# INFO: stdout 2022-06-13T16:06:25.866669:Found 464 DICOM file(s)
# 220613-16:06:25,867 nipype.interface INFO:
# 	 stdout 2022-06-13T16:06:25.866669:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# INFO: stdout 2022-06-13T16:06:25.866669:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# 220613-16:06:25,867 nipype.interface INFO:
# 	 stdout 2022-06-13T16:06:25.866669:Convert 464 DICOM as ./base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-retrans_run-3_bold (84x84x56x464)
# INFO: stdout 2022-06-13T16:06:25.866669:Convert 464 DICOM as ./base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-retrans_run-3_bold (84x84x56x464)
# 220613-16:06:29,561 nipype.interface INFO:
# 	 stdout 2022-06-13T16:06:29.561631:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-retrans_run-3_bold.nii"
# INFO: stdout 2022-06-13T16:06:29.561631:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-retrans_run-3_bold.nii"
# 220613-16:06:29,561 nipype.interface INFO:
# 	 stdout 2022-06-13T16:06:29.561631:Conversion required 6.414422 seconds (2.134033 for core code).
# INFO: stdout 2022-06-13T16:06:29.561631:Conversion required 6.414422 seconds (2.134033 for core code).
# 220613-16:06:29,616 nipype.workflow INFO:
# 	 [Node] Finished "convert".
# INFO: [Node] Finished "convert".
# 220613-16:06:31,69 nipype.workflow INFO:
# 	 [Node] Setting-up "embedder" in "/tmp/embedmeta09t4_t46/embedder".
# INFO: [Node] Setting-up "embedder" in "/tmp/embedmeta09t4_t46/embedder".
# 220613-16:06:31,117 nipype.workflow INFO:
# 	 [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# INFO: [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# 220613-16:07:00,16 nipype.workflow WARNING:
# 	 Storing result file without outputs
# WARNING: Storing result file without outputs
# 220613-16:07:00,18 nipype.workflow WARNING:
# 	 [Node] Error on "embedder" (/tmp/embedmeta09t4_t46/embedder)
# WARNING: [Node] Error on "embedder" (/tmp/embedmeta09t4_t46/embedder)
# ERROR: Embedding failed: 'NoneType' object is not subscriptable
# INFO: Post-treating /base/data/bids_data/sub-GEO053/ses-t3/func/sub-GEO053_ses-t3_task-retrans_run-3_bold.json file
# INFO: Converting /base/data/bids_data/sub-GEO053/ses-t3/fmaps/sub-GEO053_ses-t3_acq-1_epi (120 DICOMs) -> /base/data/bids_data/sub-GEO053/ses-t3/fmaps . Converter: dcm2niix . Output types: ('nii.gz',)
# 220613-16:07:00,944 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niixfcec7dcn/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niixfcec7dcn/convert".
# 220613-16:07:00,994 nipype.workflow INFO:
# 	 [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO053/ses-t3/fmaps/sub-GEO053_ses-t3_acq-1_epi -o . -s n -v n /tmp/dcm2niixfcec7dcn/convert
# INFO: [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO053/ses-t3/fmaps/sub-GEO053_ses-t3_acq-1_epi -o . -s n -v n /tmp/dcm2niixfcec7dcn/convert
# 220613-16:07:01,454 nipype.interface INFO:
# 	 stdout 2022-06-13T16:07:01.454265:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# INFO: stdout 2022-06-13T16:07:01.454265:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# 220613-16:07:01,454 nipype.interface INFO:
# 	 stdout 2022-06-13T16:07:01.454265:Found 120 DICOM file(s)
# INFO: stdout 2022-06-13T16:07:01.454265:Found 120 DICOM file(s)
# 220613-16:07:01,454 nipype.interface INFO:
# 	 stdout 2022-06-13T16:07:01.454265:slices not stacked: echo varies (TE 4.12, 6.58; echo 1, 2). Use 'merge 2D slices' option to force stacking
# INFO: stdout 2022-06-13T16:07:01.454265:slices not stacked: echo varies (TE 4.12, 6.58; echo 1, 2). Use 'merge 2D slices' option to force stacking
# 220613-16:07:01,454 nipype.interface INFO:
# 	 stdout 2022-06-13T16:07:01.454265:Convert 60 DICOM as ./base/data/bids_data/sub-GEO053/ses-t3/fmaps/sub-GEO053_ses-t3_acq-1_epi_e1 (80x80x60x1)
# INFO: stdout 2022-06-13T16:07:01.454265:Convert 60 DICOM as ./base/data/bids_data/sub-GEO053/ses-t3/fmaps/sub-GEO053_ses-t3_acq-1_epi_e1 (80x80x60x1)
# 220613-16:07:01,514 nipype.interface INFO:
# 	 stdout 2022-06-13T16:07:01.514681:Compress: "/usr/bin/pigz" -n -f -6 "./base/data/bids_data/sub-GEO053/ses-t3/fmaps/sub-GEO053_ses-t3_acq-1_epi_e1.nii"
# INFO: stdout 2022-06-13T16:07:01.514681:Compress: "/usr/bin/pigz" -n -f -6 "./base/data/bids_data/sub-GEO053/ses-t3/fmaps/sub-GEO053_ses-t3_acq-1_epi_e1.nii"
# 220613-16:07:01,514 nipype.interface INFO:
# 	 stdout 2022-06-13T16:07:01.514681:Convert 60 DICOM as ./base/data/bids_data/sub-GEO053/ses-t3/fmaps/sub-GEO053_ses-t3_acq-1_epi_e2 (80x80x60x1)
# INFO: stdout 2022-06-13T16:07:01.514681:Convert 60 DICOM as ./base/data/bids_data/sub-GEO053/ses-t3/fmaps/sub-GEO053_ses-t3_acq-1_epi_e2 (80x80x60x1)
# 220613-16:07:01,536 nipype.interface INFO:
# 	 stdout 2022-06-13T16:07:01.536288:Compress: "/usr/bin/pigz" -n -f -6 "./base/data/bids_data/sub-GEO053/ses-t3/fmaps/sub-GEO053_ses-t3_acq-1_epi_e2.nii"
# INFO: stdout 2022-06-13T16:07:01.536288:Compress: "/usr/bin/pigz" -n -f -6 "./base/data/bids_data/sub-GEO053/ses-t3/fmaps/sub-GEO053_ses-t3_acq-1_epi_e2.nii"
# 220613-16:07:01,536 nipype.interface INFO:
# 	 stdout 2022-06-13T16:07:01.536288:Conversion required 0.410165 seconds (0.147339 for core code).
# INFO: stdout 2022-06-13T16:07:01.536288:Conversion required 0.410165 seconds (0.147339 for core code).
# 220613-16:07:01,570 nipype.workflow INFO:
# 	 [Node] Finished "convert".
# INFO: [Node] Finished "convert".
# WARNING: Failed to find task field in /base/data/bids_data/sub-GEO053/ses-t3/fmaps/sub-GEO053_ses-t3_acq-1_echo-1_epi.json.
# WARNING: Failed to find task field in /base/data/bids_data/sub-GEO053/ses-t3/fmaps/sub-GEO053_ses-t3_acq-1_echo-2_epi.json.
# WARNING: For now not embedding BIDS and info generated .nii.gz itself since sequence produced multiple files
# INFO: Converting /base/data/bids_data/sub-GEO053/ses-t3/fmaps/sub-GEO053_ses-t3_acq-2_epi (60 DICOMs) -> /base/data/bids_data/sub-GEO053/ses-t3/fmaps . Converter: dcm2niix . Output types: ('nii.gz',)
# 220613-16:07:02,312 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niixx8j8clf5/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niixx8j8clf5/convert".
# 220613-16:07:02,353 nipype.workflow INFO:
# 	 [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO053/ses-t3/fmaps/sub-GEO053_ses-t3_acq-2_epi -o . -s n -v n /tmp/dcm2niixx8j8clf5/convert
# INFO: [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO053/ses-t3/fmaps/sub-GEO053_ses-t3_acq-2_epi -o . -s n -v n /tmp/dcm2niixx8j8clf5/convert
# 220613-16:07:02,672 nipype.interface INFO:
# 	 stdout 2022-06-13T16:07:02.671740:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# INFO: stdout 2022-06-13T16:07:02.671740:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# 220613-16:07:02,672 nipype.interface INFO:
# 	 stdout 2022-06-13T16:07:02.671740:Found 60 DICOM file(s)
# INFO: stdout 2022-06-13T16:07:02.671740:Found 60 DICOM file(s)
# 220613-16:07:02,672 nipype.interface INFO:
# 	 stdout 2022-06-13T16:07:02.671740:Convert 60 DICOM as ./base/data/bids_data/sub-GEO053/ses-t3/fmaps/sub-GEO053_ses-t3_acq-2_epi_e2_ph (80x80x60x1)
# INFO: stdout 2022-06-13T16:07:02.671740:Convert 60 DICOM as ./base/data/bids_data/sub-GEO053/ses-t3/fmaps/sub-GEO053_ses-t3_acq-2_epi_e2_ph (80x80x60x1)
# 220613-16:07:02,691 nipype.interface INFO:
# 	 stdout 2022-06-13T16:07:02.691632:Compress: "/usr/bin/pigz" -n -f -6 "./base/data/bids_data/sub-GEO053/ses-t3/fmaps/sub-GEO053_ses-t3_acq-2_epi_e2_ph.nii"
# INFO: stdout 2022-06-13T16:07:02.691632:Compress: "/usr/bin/pigz" -n -f -6 "./base/data/bids_data/sub-GEO053/ses-t3/fmaps/sub-GEO053_ses-t3_acq-2_epi_e2_ph.nii"
# 220613-16:07:02,691 nipype.interface INFO:
# 	 stdout 2022-06-13T16:07:02.691632:Conversion required 0.192270 seconds (0.065787 for core code).
# INFO: stdout 2022-06-13T16:07:02.691632:Conversion required 0.192270 seconds (0.065787 for core code).
# 220613-16:07:02,730 nipype.workflow INFO:
# 	 [Node] Finished "convert".
# INFO: [Node] Finished "convert".
# WARNING: Failed to find task field in /base/data/bids_data/sub-GEO053/ses-t3/fmaps/sub-GEO053_ses-t3_acq-2_epi.json.
# 220613-16:07:02,898 nipype.workflow INFO:
# 	 [Node] Setting-up "embedder" in "/tmp/embedmetals156k3t/embedder".
# INFO: [Node] Setting-up "embedder" in "/tmp/embedmetals156k3t/embedder".
# 220613-16:07:02,940 nipype.workflow INFO:
# 	 [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# INFO: [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# 220613-16:07:05,253 nipype.workflow WARNING:
# 	 Storing result file without outputs
# WARNING: Storing result file without outputs
# 220613-16:07:05,254 nipype.workflow WARNING:
# 	 [Node] Error on "embedder" (/tmp/embedmetals156k3t/embedder)
# WARNING: [Node] Error on "embedder" (/tmp/embedmetals156k3t/embedder)
# ERROR: Embedding failed: 'NoneType' object is not subscriptable
# INFO: Post-treating /base/data/bids_data/sub-GEO053/ses-t3/fmaps/sub-GEO053_ses-t3_acq-2_epi.json file
# INFO: Lock 140638704426176 acquired on /base/data/bids_data/heudiconv.lock
# INFO: Populating template files under /base/data/bids_data/
# INFO: Lock 140638704426176 released on /base/data/bids_data/heudiconv.lock
# INFO: PROCESSING DONE: {'subject': 'GEO053', 'outdir': '/base/data/bids_data/', 'session': 't3'}
