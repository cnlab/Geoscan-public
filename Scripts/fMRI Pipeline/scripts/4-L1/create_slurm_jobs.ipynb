# %% [markdown]
# ## Run to create slurm job
#
# model_path = [path to .json template]
# %run [path to l1analysis_notebook.ipynb]

# %%
model_path = '/data00/projects/geoscan_v2/scripts/L1/model_images-GEO.json'
# %run '/data00/projects/geoscan_v2/scripts/L1/l1analysis_notebook.ipynb'
# Out:
# Using template study-geoscanR01-GEO.json: GEoscan R01 default pipeline
# 	6mm FWHM smoothing
# 	No global scaling
# 	FAST correlation
# 	x_trans, y_trans, z_trans, x_rot, y_rot, z_rot, csf, trash regressor (FD > 0.75 | GS > 3 SD)
# Using template task_images-GEO.json: Geoscan Image Task
# ----
# Processing 8 participants:
# ['GEO015', 'GEO033', 'GEO036', 'GEO037', 'GEO053', 'GEO061', 'GEO067', 'GEO071']
# ----
# GEO015 : job created
# GEO033 : job created
# GEO036 : job created
# GEO037 : job created
# GEO053 : job created
# GEO061 : job created
# GEO067 : job created
# GEO071 : job created
# ----
# To test drive one job (sub-GEO071), copy and paste the following lines in terminal:
#
# singularity run --cleanenv \
#   -B /data00/projects/geoscan_v2/scripts/L1/l1analysis_SPM.py:/worker.py \
#   -B /data00/projects/geoscan_v2:/data \
#   -B /data00/projects/geoscan_v2/data/bids_data/derivatives/nipype:/output \
#   -B /data00/projects/geoscan_v2/data/bids_data/working/nipype:/working \
#   -B /data00/projects/geoscan_v2/models/task-image_model-GEO-condition/jobs/sub-GEO071.json:/job.json \
#   /data00/tools/singularity_images/neurodocker.sqsh python /worker.py /job.json
# ----
# Alternatively, submit the whole batch by copying and pasting the following lines in terminal:
#
# cd /data00/projects/geoscan_v2/models/task-image_model-GEO-condition/slurm
# sbatch -D /data00/projects/geoscan_v2/models/task-image_model-GEO-condition/slurm -c 8 sub-GEO015.job
# sbatch -D /data00/projects/geoscan_v2/models/task-image_model-GEO-condition/slurm -c 8 sub-GEO033.job
# sbatch -D /data00/projects/geoscan_v2/models/task-image_model-GEO-condition/slurm -c 8 sub-GEO036.job
# sbatch -D /data00/projects/geoscan_v2/models/task-image_model-GEO-condition/slurm -c 8 sub-GEO037.job
# sbatch -D /data00/projects/geoscan_v2/models/task-image_model-GEO-condition/slurm -c 8 sub-GEO053.job
# sbatch -D /data00/projects/geoscan_v2/models/task-image_model-GEO-condition/slurm -c 8 sub-GEO061.job
# sbatch -D /data00/projects/geoscan_v2/models/task-image_model-GEO-condition/slurm -c 8 sub-GEO067.job
# sbatch -D /data00/projects/geoscan_v2/models/task-image_model-GEO-condition/slurm -c 8 sub-GEO071.job

# %%
def show_DM(spm_file):
    import os
    import matplotlib.pylab as plt
    import pandas as pd
    import scipy.io as sio
    from nistats import reporting
    
    # %matplotlib inline 
    
    if not os.path.exists(spm_file):
        print('Cannot find SPM.mat file')
        return False
    
    spm_mat=sio.loadmat(spm_file, 
               squeeze_me=True, struct_as_record=False)
    
    DM = spm_mat['SPM'].xX.X
    regressor_labels = spm_mat['SPM'].xX.name
    
    design_matrix = pd.DataFrame(DM, columns=regressor_labels)
    fig,ax = plt.subplots(figsize=(10,16))
    reporting.plot_design_matrix(design_matrix, ax=ax, rescale=True)
    plt.show()

# %%
show_DM('/data00/projects/geoscan_v2/data/bids_data/derivatives/nipype/task-image_model-condition/sub-GS017/SPM.mat')
