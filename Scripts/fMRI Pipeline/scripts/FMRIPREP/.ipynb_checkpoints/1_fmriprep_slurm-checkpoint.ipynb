# %% [markdown]
# # Using `fmriprep` on the SLURM cluster
#
#
#
# --------------------
#
#
# #### HISTORY
#
# * 7/9/2021 - dcosme revised for bbprime
# * 5/22/20 - mbod updated for revised MURI fmriprep pipeline
# * 1/22/20 - matt, jeesung and nicole initial test setup for using SLURM

# %%
import os

# %% [markdown]
# ## 1. Create job files
#
# * Each process that you send to SLURM needs a job file, which is a text file with the commands to be executed by SLURM
#
# * For the bbprime project these job files should be placed in:
#
# ```
# /data00/projects/geoscan_v2/scripts/FMRIPREP/jobs
# ```
#
# * A job file has:
#
#     1. some SLURM directives in lines beginning `#SBATCH`
#     2. one or more commands to be run (prefixed with `srun`)
#
# ```
# #!/bin/bash
# #SBATCH --job-name=fmriprep_{ID}.job
# #SBATCH --output=out/fmriprep_{ID}.out
# #SBATCH --error=out/fmriprep_{ID}.err
# #SBATCH --time=2-00:00
#
# srun singularity run --cleanenv \
#     -B /data00/tools/freesurfer/license.txt:/opt/freesurfer/license.txt  \
#     -B /data00/projects/geoscan_v2/data/bids_data:/data \
#     -B /data00/projects/geoscan_v2/data/bids_data/derivatives:/out  \
#     -B /data00/projects/geoscan_v2/data/bids_data/derivatives/working:/work \
#     /data00/tools/singularity_images/fmriprep_v20.0.6 /data /out -w /work \
#     --ignore slicetiming \
#     --nthread 8 \
#     participant --participant_label {ID} \
#     --skip-bids-validation
# ```

# %% [markdown]
# ### Define variables

# %%
project = 'geoscan_v2'
project_dir = os.path.join('/data00/projects', project)
slurm_dir = os.path.join(project_dir, 'scripts/FMRIPREP/jobs')
os.makedirs(slurm_dir, exist_ok=True)

# %% [markdown]
# ### Create job template

# %% [markdown]
# OLD VERSION: Fieldmap correction

# %%
job_file_template = r'''#!/bin/bash
#SBATCH --job-name=fmriprep_{ID}.job
#SBATCH --output=out/fmriprep_{ID}.out
#SBATCH --error=out/fmriprep_{ID}.err
#SBATCH --time=2-00:00

srun singularity run --cleanenv \
    -B /data00/tools/freesurfer/license.txt:/opt/freesurfer/license.txt  \
    -B /data00/projects/geoscan_v2/data/bids_data:/data \
    -B /data00/projects/geoscan_v2/data/bids_data/derivatives:/out  \
    -B /data00/projects/geoscan_v2/data/bids_data/derivatives/working:/work \
    --home /home/fmriprep \
    /data00/tools/singularity_images/fmriprep-25.0.0.simg /data /out -w /work \
    --ignore slicetiming \
    --nthread 8 \
    participant --participant_label {ID} \
    --skip-bids-validation
'''

# %% [markdown]
# NEW VERSION: Fieldmap-less correction, and no correction version

# %%
job_file_template = r'''#!/bin/bash
#SBATCH --job-name=fmriprep-syn_{ID}.job
#SBATCH --output=out/fmriprep-syn_{ID}.out
#SBATCH --error=out/fmriprep-syn_{ID}.err
#SBATCH --time=2-00:00

srun singularity run --cleanenv \
    -B /data00/tools/freesurfer/license.txt:/opt/freesurfer/license.txt  \
    -B /data00/projects/geoscan_v2/data/bids_data:/data \
    -B /data00/projects/geoscan_v2/data/bids_data/derivatives:/out  \
    -B /data00/projects/geoscan_v2/data/bids_data/derivatives/working:/work \
    /data00/tools/singularity_images/fmriprep_v20.0.6 /data /out -w /work \
    --ignore slicetiming fieldmaps \
    --use-syn-sdc \
    --nthread 8 \
    participant --participant_label {ID} \
    --skip-bids-validation
'''

# %%
job_file_template = r'''#!/bin/bash
#SBATCH --job-name=fmriprep-nocorrection_{ID}.job
#SBATCH --output=out/fmriprep-nocorrection_{ID}.out
#SBATCH --error=out/fmriprep-nocorrection_{ID}.err
#SBATCH --time=2-00:00
#SBATCH --cpus-per-task=6
#SBATCH --mem=15GB

srun singularity run --cleanenv \
    -B /data00/tools/freesurfer/license.txt:/opt/freesurfer/license.txt  \
    -B /data00/projects/geoscan_v2/data/bids_data:/data \
    -B /data00/projects/geoscan_v2/data/bids_data/derivatives_nocorrection:/out  \
    -B /data00/projects/geoscan_v2/data/bids_data/derivatives_nocorrection/working:/work \
    -B /data00/projects/geoscan_v2/scripts/FMRIPREP/home_dir:/home/fmriprep \
    --home /home/fmriprep \
    /data00/tools/singularity_images/fmriprep-25.0.0.simg \
    /data /out participant \
    --participant-label {ID} \
    -w /work \
    --ignore slicetiming fieldmaps \
    --nthreads 8 \
    --skip-bids-validation
        
'''

# %%
print(job_file_template.format(ID='sub-GS005'))
# Out:
# #!/bin/bash
# #SBATCH --job-name=fmriprep-noSDC_sub-GS005.job
# #SBATCH --output=out/fmriprep-noSDC_sub-GS005.out
# #SBATCH --error=out/fmriprep-noSDC_sub-GS005.err
# #SBATCH --time=2-00:00
#
# srun singularity run --cleanenv \
#     -B /data00/tools/freesurfer/license.txt:/opt/freesurfer/license.txt  \
#     -B /data00/projects/geoscan_v2/data/bids_data:/data \
#     -B /data00/projects/geoscan_v2/data/bids_data/derivatives_noSDC:/out  \
#     -B /data00/projects/geoscan_v2/data/bids_data/derivatives_noSDC/working:/work \
#     -B /data00/projects/geoscab_v2/scripts/FMRIPREP/home_dir:/home/fmriprep \
#     --home /home/fmriprep \
#     /data00/tools/singularity_images/fmriprep-25.0.0.simg /data /out -w /work \
#     --ignore slicetiming fieldmaps \
#     --nthread 8 \
#     participant --participant_label sub-GS005 \
#     --skip-bids-validation

# %% [markdown]
# ### Identify participants who lack job files
# Of the participants listed in the `{project_dir}/data/bids_data`, identify those who lack a job file and create it

# %%
subs = [s for s in os.listdir(os.path.join(project_dir, 'data/bids_data'))
                       if s.startswith('sub-GEO')]

existing_job_files = [s for s in os.listdir(slurm_dir)
                       if s.endswith('.job') and s.count('sub-GS')==1]
existing_job_files=[]
subs_to_process = [sub for sub in subs if 'fmriprep-noSDC_' + sub + '.job' not in existing_job_files]

# %%
subs_to_process
# Out:
# ['sub-GEO004',
#  'sub-GEO006',
#  'sub-GEO010',
#  'sub-GEO013',
#  'sub-GEO015',
#  'sub-GEO021',
#  'sub-GEO022',
#  'sub-GEO033',
#  'sub-GEO036',
#  'sub-GEO037',
#  'sub-GEO047',
#  'sub-GEO053',
#  'sub-GEO061',
#  'sub-GEO064',
#  'sub-GEO067',
#  'sub-GEO068',
#  'sub-GEO070',
#  'sub-GEO071',
#  'sub-GEO073',
#  'sub-GEO074',
#  'sub-GEO078']

# %% [markdown]
# ### Create a job file for each participant in `subs_to_process`

# %%
for s in subs_to_process:
    file_path = os.path.join(slurm_dir, 'fmriprep-nocorrection_{}.job').format(s)
    print('Creating', file_path)

    with open(file_path.format(s), 'w') as job:
        job.write(job_file_template.format(ID=s))
# Out:
# Creating /data00/projects/geoscan_v2/scripts/FMRIPREP/jobs/fmriprep-nocorrection_sub-GEO004.job
# Creating /data00/projects/geoscan_v2/scripts/FMRIPREP/jobs/fmriprep-nocorrection_sub-GEO006.job
# Creating /data00/projects/geoscan_v2/scripts/FMRIPREP/jobs/fmriprep-nocorrection_sub-GEO010.job
# Creating /data00/projects/geoscan_v2/scripts/FMRIPREP/jobs/fmriprep-nocorrection_sub-GEO013.job
# Creating /data00/projects/geoscan_v2/scripts/FMRIPREP/jobs/fmriprep-nocorrection_sub-GEO015.job
# Creating /data00/projects/geoscan_v2/scripts/FMRIPREP/jobs/fmriprep-nocorrection_sub-GEO021.job
# Creating /data00/projects/geoscan_v2/scripts/FMRIPREP/jobs/fmriprep-nocorrection_sub-GEO022.job
# Creating /data00/projects/geoscan_v2/scripts/FMRIPREP/jobs/fmriprep-nocorrection_sub-GEO033.job
# Creating /data00/projects/geoscan_v2/scripts/FMRIPREP/jobs/fmriprep-nocorrection_sub-GEO036.job
# Creating /data00/projects/geoscan_v2/scripts/FMRIPREP/jobs/fmriprep-nocorrection_sub-GEO037.job
# Creating /data00/projects/geoscan_v2/scripts/FMRIPREP/jobs/fmriprep-nocorrection_sub-GEO047.job
# Creating /data00/projects/geoscan_v2/scripts/FMRIPREP/jobs/fmriprep-nocorrection_sub-GEO053.job
# Creating /data00/projects/geoscan_v2/scripts/FMRIPREP/jobs/fmriprep-nocorrection_sub-GEO061.job
# Creating /data00/projects/geoscan_v2/scripts/FMRIPREP/jobs/fmriprep-nocorrection_sub-GEO064.job
# Creating /data00/projects/geoscan_v2/scripts/FMRIPREP/jobs/fmriprep-nocorrection_sub-GEO067.job
# Creating /data00/projects/geoscan_v2/scripts/FMRIPREP/jobs/fmriprep-nocorrection_sub-GEO068.job
# Creating /data00/projects/geoscan_v2/scripts/FMRIPREP/jobs/fmriprep-nocorrection_sub-GEO070.job
# Creating /data00/projects/geoscan_v2/scripts/FMRIPREP/jobs/fmriprep-nocorrection_sub-GEO071.job
# Creating /data00/projects/geoscan_v2/scripts/FMRIPREP/jobs/fmriprep-nocorrection_sub-GEO073.job
# Creating /data00/projects/geoscan_v2/scripts/FMRIPREP/jobs/fmriprep-nocorrection_sub-GEO074.job
# Creating /data00/projects/geoscan_v2/scripts/FMRIPREP/jobs/fmriprep-nocorrection_sub-GEO078.job

# %% [markdown]
# ## 2. Submit jobs to SLURM cluster
#
# ### How to log onto the SLURM master
#
#
# * master name: `cls000.asc.upenn.edu`
#
#
# ```
# ssh <JANUS_UN>@asc.upenn.edu@cls000
# ```
#
#
# * This will give you a terminal on the SLURM master node where you can look at the process queue and schedule jobs.
#
# ### How to schedule a job to SLURM
#
# * Use the `sbatch` command
#
#     ```
#     sbatch -D /data00/slurm_jobs/slurm_bbprime -c 8 name_of_job_file
#
#     ```
#
#     * `-D` is the working directory
#     * `-c` the number of processors to use
#     * then the name of the job file

# %% [markdown]
# ### Create log file directory
#
# If this doesn't exist, your job will fail without explanation

# %%
os.makedirs(os.path.join(slurm_dir, 'out'), exist_ok=True)

# %% [markdown]
# ### Run all jobs
# To submit all the jobs, copy and past the following lines of code into the terminal after logging into the slurm cluster

# %%
print("Alternatively, submit the whole batch by copying and pasting the following lines in terminal:")
print("")

print(f"cd {slurm_dir}")
for s in subs_to_process:
    print(f"sbatch -D {slurm_dir} -c 8 fmriprep-nocorrection_{s}.job")
print(" ")
# Out:
# Alternatively, submit the whole batch by copying and pasting the following lines in terminal:
#
# cd /data00/projects/geoscan_v2/scripts/FMRIPREP/jobs
# sbatch -D /data00/projects/geoscan_v2/scripts/FMRIPREP/jobs -c 8 fmriprep-nocorrection_sub-GEO004.job
# sbatch -D /data00/projects/geoscan_v2/scripts/FMRIPREP/jobs -c 8 fmriprep-nocorrection_sub-GEO006.job
# sbatch -D /data00/projects/geoscan_v2/scripts/FMRIPREP/jobs -c 8 fmriprep-nocorrection_sub-GEO010.job
# sbatch -D /data00/projects/geoscan_v2/scripts/FMRIPREP/jobs -c 8 fmriprep-nocorrection_sub-GEO013.job
# sbatch -D /data00/projects/geoscan_v2/scripts/FMRIPREP/jobs -c 8 fmriprep-nocorrection_sub-GEO015.job
# sbatch -D /data00/projects/geoscan_v2/scripts/FMRIPREP/jobs -c 8 fmriprep-nocorrection_sub-GEO021.job
# sbatch -D /data00/projects/geoscan_v2/scripts/FMRIPREP/jobs -c 8 fmriprep-nocorrection_sub-GEO022.job
# sbatch -D /data00/projects/geoscan_v2/scripts/FMRIPREP/jobs -c 8 fmriprep-nocorrection_sub-GEO033.job
# sbatch -D /data00/projects/geoscan_v2/scripts/FMRIPREP/jobs -c 8 fmriprep-nocorrection_sub-GEO036.job
# sbatch -D /data00/projects/geoscan_v2/scripts/FMRIPREP/jobs -c 8 fmriprep-nocorrection_sub-GEO037.job
# sbatch -D /data00/projects/geoscan_v2/scripts/FMRIPREP/jobs -c 8 fmriprep-nocorrection_sub-GEO047.job
# sbatch -D /data00/projects/geoscan_v2/scripts/FMRIPREP/jobs -c 8 fmriprep-nocorrection_sub-GEO053.job
# sbatch -D /data00/projects/geoscan_v2/scripts/FMRIPREP/jobs -c 8 fmriprep-nocorrection_sub-GEO061.job
# sbatch -D /data00/projects/geoscan_v2/scripts/FMRIPREP/jobs -c 8 fmriprep-nocorrection_sub-GEO064.job
# sbatch -D /data00/projects/geoscan_v2/scripts/FMRIPREP/jobs -c 8 fmriprep-nocorrection_sub-GEO067.job
# sbatch -D /data00/projects/geoscan_v2/scripts/FMRIPREP/jobs -c 8 fmriprep-nocorrection_sub-GEO068.job
# sbatch -D /data00/projects/geoscan_v2/scripts/FMRIPREP/jobs -c 8 fmriprep-nocorrection_sub-GEO070.job
# sbatch -D /data00/projects/geoscan_v2/scripts/FMRIPREP/jobs -c 8 fmriprep-nocorrection_sub-GEO071.job
# sbatch -D /data00/projects/geoscan_v2/scripts/FMRIPREP/jobs -c 8 fmriprep-nocorrection_sub-GEO073.job
# sbatch -D /data00/projects/geoscan_v2/scripts/FMRIPREP/jobs -c 8 fmriprep-nocorrection_sub-GEO074.job
# sbatch -D /data00/projects/geoscan_v2/scripts/FMRIPREP/jobs -c 8 fmriprep-nocorrection_sub-GEO078.job
